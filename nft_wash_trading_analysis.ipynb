# %% [markdown]
# <h1> <center> Opensea Analysis </center> </h1>

# %% [markdown]
# ### Importing entire historical NFT Transaction data from 4th Feb 2018 to 27th April 2021

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\LENOVO\Desktop\Data_API.csv')

# Generating the starting 5 entries in the data 
data_top= data.head()
data_top
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\2537021014.py:3: DtypeWarning: Columns (0,1,2,4,6,8,9,10,14,15,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\Users\LENOVO\Desktop\Data_API.csv')
#   Smart_contract    ID_token  \
# 0            NaN  87094722.0
# 1            NaN  73044643.0
# 2            NaN  17107482.0
# 3            NaN  82230857.0
# 4            NaN  40925443.0
#
#                                     Transaction_hash  \
# 0  0xed9ff1c311a611e5c457ce0a49bbbb7ed55efca98842...
# 1  0xbc8412594ffa7382e8306215ece5b4e041fc641b1813...
# 2  0x92672baf5e9e23de230dee8e57ddf443ab6d5a336341...
# 3  0x3d157249e3083622c2d756f07a05caa3a76687288b32...
# 4  0xa892b3569dc8e6b3c7db93aade62372637ebbc61fb63...
#
#                                Seller_address Seller_username  \
# 0  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 1  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 2  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 3  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 4  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
#
#                                 Buyer_address Buyer_username  \
# 0  0xe0fb7622091e3d9ef9b438471b10b9ea88c7cf6b            NaN
# 1  0x2c00d05ff7ffe93d77145dfe12aa56e622ae6f40            NaN
# 2  0xe0fb7622091e3d9ef9b438471b10b9ea88c7cf6b            NaN
# 3  0x2c00d05ff7ffe93d77145dfe12aa56e622ae6f40            NaN
# 4  0x2c00d05ff7ffe93d77145dfe12aa56e622ae6f40            NaN
#
#                                   Image_url_1 Image_url_2 Image_url_3  ...  \
# 0   https://card.godsunchained.com/?id=33&q=4         NaN         NaN  ...
# 1   https://card.godsunchained.com/?id=79&q=4         NaN         NaN  ...
# 2   https://card.godsunchained.com/?id=33&q=4         NaN         NaN  ...
# 3  https://card.godsunchained.com/?id=227&q=4         NaN         NaN  ...
# 4   https://card.godsunchained.com/?id=62&q=4         NaN         NaN  ...
#
#   Name  Description     Collection         Market     Datetime_updated  \
# 0  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 1  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 2  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 3  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 4  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
#
#   Datetime_updated_seconds Permanent_link             Unique_id_collection  \
# 0      2019-11-30 23:59:33            NaN  ('Godsunchained', '87094722.0')
# 1      2019-11-30 23:59:33            NaN  ('Godsunchained', '73044643.0')
# 2      2019-11-30 23:59:33            NaN  ('Godsunchained', '17107482.0')
# 3      2019-11-30 23:59:33            NaN  ('Godsunchained', '82230857.0')
# 4      2019-11-30 23:58:44            NaN  ('Godsunchained', '40925443.0')
#
#   Collection_cleaned Category
# 0      Godsunchained    Games
# 1      Godsunchained    Games
# 2      Godsunchained    Games
# 3      Godsunchained    Games
# 4      Godsunchained    Games
#
# [5 rows x 24 columns]

# %%
data.Market.unique()
# Out:
# array(['Godsunchained', 'Cryptokitties', 'Atomic', 'Decentraland',
#        'OpenSea'], dtype=object)

# %%
# Number of rows and columns in the data
data.shape
# Out:
# (6071027, 24)

# %% [markdown]
# ### Filtering the data to get all NFT transactions in the OpenSea marketplace

# %%
opensea= data[data.Market.isin(['OpenSea'])]
opensea.head()
# Out:
#                                      Smart_contract ID_token  \
# 4163765  0x06012c8cf97bead5deae237070f9587f8e7a266d   570964
# 4163766  0x06012c8cf97bead5deae237070f9587f8e7a266d   553057
# 4163767  0x06012c8cf97bead5deae237070f9587f8e7a266d   422030
# 4163768  0x06012c8cf97bead5deae237070f9587f8e7a266d   551265
# 4163769  0x06012c8cf97bead5deae237070f9587f8e7a266d   561824
#
#                                           Transaction_hash  \
# 4163765  0xb9fa19b74de10a091c53043aa9f9d84c3233366a0abf...
# 4163766  0x1e886781c29a6fa6cb02d5b5407a125194930b9cd20e...
# 4163767  0x7bb2f01c8d30383927ba677efb0ead9a3d796e8bdf24...
# 4163768  0x78dfb2e6f8fd82f811eddbbc495bf7e0206284c85244...
# 4163769  0xf465d5c0736e522b152c380331d45c0886d0e17eadb6...
#
#                                      Seller_address Seller_username  \
# 4163765  0xa21037849678af57f9865c6b9887f4e339f6377a             NaN
# 4163766  0x491677edd34020bf644fd63b5d65113fb3b74b10             NaN
# 4163767  0xe357cbc0a5dfa4c238b769d065416d15fb56d8f9             NaN
# 4163768  0xc4d4672f651bf72414be1f828952480ccf0b2a8f             NaN
# 4163769  0x7045540552d1fcc2ab1eb64e1f868aeb490606fa       stealtime
#
#                                       Buyer_address Buyer_username  \
# 4163765  0x442dccee68425828c106a3662014b4f131e3bd9b          j1mmy
# 4163766  0xf165d353abddb7cb00052d610254249fcc12a8c7     cyberberry
# 4163767  0x24a6f141b18f27f65a1ba8b49e2d975d18e1a259            NaN
# 4163768  0x5b897d015dbb2661e1fd4a0df68322dfaec6ea14            NaN
# 4163769  0xb58092199e8b47bd9e27533d9504282eb802c446            NaN
#
#                                                Image_url_1  \
# 4163765  https://lh3.googleusercontent.com/QHS7oRZx3hnv...
# 4163766  https://storage.opensea.io/0x06012c8cf97bead5d...
# 4163767  https://storage.opensea.io/0x06012c8cf97bead5d...
# 4163768  https://storage.opensea.io/0x06012c8cf97bead5d...
# 4163769  https://storage.opensea.io/0x06012c8cf97bead5d...
#
#                                                Image_url_2  \
# 4163765  https://img.cryptokitties.co/0x06012c8cf97bead...
# 4163766  https://img.cryptokitties.co/0x06012c8cf97bead...
# 4163767  https://img.cryptokitties.co/0x06012c8cf97bead...
# 4163768  https://img.cryptokitties.co/0x06012c8cf97bead...
# 4163769  https://img.cryptokitties.co/0x06012c8cf97bead...
#
#                                                Image_url_3  ...  \
# 4163765  https://lh3.googleusercontent.com/QHS7oRZx3hnv...  ...
# 4163766  https://storage.opensea.io/0x06012c8cf97bead5d...  ...
# 4163767  https://storage.opensea.io/0x06012c8cf97bead5d...  ...
# 4163768  https://storage.opensea.io/0x06012c8cf97bead5d...  ...
# 4163769  https://storage.opensea.io/0x06012c8cf97bead5d...  ...
#
#                            Name  \
# 4163765           Wiley Breeder
# 4163766                     NaN
# 4163767        Wolfgrey breeder
# 4163768  🔥Flamin' Forrest Lord🔥
# 4163769                     NaN
#
#                                                Description     Collection  \
# 4163765  Shalom! Wiley Breeder here. I'm here to enjoy ...  Cryptokitties
# 4163766  *deadpan stare*. I'm Kitty #553057. If you als...  Cryptokitties
# 4163767  Shalom! I'm Wolfgrey breeder. In high school, ...  Cryptokitties
# 4163768  G'day! I'm 🔥Flamin' Forrest Lord🔥. All you nee...  Cryptokitties
# 4163769  Sup. I'm Kitty #561824. My friends describe me...  Cryptokitties
#
#           Market     Datetime_updated Datetime_updated_seconds  \
# 4163765  OpenSea  2018-03-01 00:00:00      2018-03-01 00:01:30
# 4163766  OpenSea  2018-03-01 00:00:00      2018-03-01 00:00:01
# 4163767  OpenSea  2018-02-28 00:00:00      2018-02-28 23:59:19
# 4163768  OpenSea  2018-02-28 00:00:00      2018-02-28 23:55:17
# 4163769  OpenSea  2018-02-28 00:00:00      2018-02-28 23:54:07
#
#                                             Permanent_link  \
# 4163765  https://opensea.io/assets/0x06012c8cf97bead5de...
# 4163766  https://opensea.io/assets/0x06012c8cf97bead5de...
# 4163767  https://opensea.io/assets/0x06012c8cf97bead5de...
# 4163768  https://opensea.io/assets/0x06012c8cf97bead5de...
# 4163769  https://opensea.io/assets/0x06012c8cf97bead5de...
#
#                 Unique_id_collection Collection_cleaned Category
# 4163765  ('Cryptokitties', '570964')       Cryptokittie      Art
# 4163766  ('Cryptokitties', '553057')       Cryptokittie      Art
# 4163767  ('Cryptokitties', '422030')       Cryptokittie      Art
# 4163768  ('Cryptokitties', '551265')       Cryptokittie      Art
# 4163769  ('Cryptokitties', '561824')       Cryptokittie      Art
#
# [5 rows x 24 columns]

# %%
# Number of rows and columns in the OpenSea data
opensea.shape
# Out:
# (1907262, 24)

# %% [markdown]
# ### Starting and Ending Date for the transactions

# %%
opensea['Datetime_updated_seconds'].min()
# Out:
# '2018-02-04 06:33:49'

# %%
opensea['Datetime_updated_seconds'].max()
# Out:
# '2021-04-27 23:59:51'

# %% [markdown]
# ### Names of different columns present in the data

# %%
opensea.columns
# Out:
# Index(['Smart_contract', 'ID_token', 'Transaction_hash', 'Seller_address',
#        'Seller_username', 'Buyer_address', 'Buyer_username', 'Image_url_1',
#        'Image_url_2', 'Image_url_3', 'Image_url_4', 'Price_Crypto', 'Crypto',
#        'Price_USD', 'Name', 'Description', 'Collection', 'Market',
#        'Datetime_updated', 'Datetime_updated_seconds', 'Permanent_link',
#        'Unique_id_collection', 'Collection_cleaned', 'Category'],
#       dtype='object')

# %% [markdown]
# ### Types of unique crypto amd categories present

# %%
opensea['Crypto'].unique()
# Out:
# array(['ETH', 'MANA', 'WETH', 'BZN', 'USDC', 'SAI', 'EMONT', 'IMP', 'NVT',
#        'LESS', 'GUSD', 'ENJ', 'ELET', 'WCK', 'GPL', 'WMC', 'WAXIE',
#        'OLDWZX', 'OLDWAXIE', 'BLVD', 'MBC', 'HUE', 'DAPPT', 'SKULL',
#        'CUBE', 'DAI', 'MATIC', 'GOU', 'BON', 'YUMI', 'SLP', 'BAT', 'LIT',
#        'MX', '0xBTC', 'CURIO', 'BPC', 'HIVED', 'HOUR', 'MM', 'WGM', 'KOI',
#        'RCC', 'JBG', '1MT', 'GCASH', 'PYRO', 'MNFT', 'KIWI', 'DOOM',
#        'AMPL', 'DUST', 'VSF', 'GMX', 'BUDGET', 'FRFY', 'CPT', 'CHERRY',
#        'NEWS', 'MORK', 'GOOSE', 'RCDY', 'ARCONA', 'PIXEL', 'SAL', 'DGX',
#        'RARE', 'WAIF', 'FTHR', 'MEME', 'SAND', 'UNI', 'GALA', 'COIN',
#        'BONES', 'MCX', 'RAINBOW', 'COVAL', 'ROPE', 'TRSH', 'VI', 'WIPC',
#        'BOOB', 'ECTO', 'INK', 'LINK', 'KEK-DEP', 'FIRST', 'SWAG', 'GEM',
#        'GOKU', 'RODZ', 'VEGETA', 'ABST', 'TATR', 'EPIC', 'LOAD', 'CAMEL',
#        'FUD', 'CRED', 'DDIM', 'KLTR', 'BAEPAY', 'eFAME', 'KEK', 'KING',
#        'PPDEX', 'SURF', 'TRIP', 'LAR', 'PRIME', 'JGN', 'RUGZ', 'BASED',
#        'PXART', 'WBTC', 'REVV', 'DENA', 'SMTS', 'EGGS', 'VIDEO', 'EBB',
#        'DHC', 'MGDv2', 'ATRI', 'ZURU', 'ART', 'TRISM', 'AVRT', 'THREE',
#        '2XDN', 'B0T', 'PGU', 'ELAND', 'BORG', 'YGT', 'NUGS', 'ECAT',
#        'FTM', 'ASLT', 'KAP', 'NDR', 'RARI', 'BONDLY', 'PLAY', 'CHONK',
#        'ROT', 'VIDT', 'XMON', 'BUDZ', 'MKR', 'ANRX', 'CGG', 'PMON', 'RLY',
#        'INI', 'ZUT', 'ZIOT', 'PIXIE'], dtype=object)

# %%
print("There are", len(opensea['Crypto'].unique()),"types of cryptocurrencies present in the data")
# Out:
# There are 159 types of cryptocurrencies present in the data

# %%
# Types of categories
opensea['Category'].unique()
# Out:
# array(['Art', 'Other', 'Collectible', 'Games', 'Metaverse', 'Utility'],
#       dtype=object)

# %% [markdown]
# ### Unique values in different types of categories

# %%
# For the entire data
pd.value_counts(data.Category)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\115030275.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(data.Category)
# Category
# Games          2643014
# Collectible    1605657
# Art            1472515
# Other           272772
# Metaverse        68372
# Utility           8697
# Name: count, dtype: int64

# %%
# For the opensea data
pd.value_counts(opensea.Category)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\3327894944.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(opensea.Category)
# Category
# Games          749306
# Art            633493
# Collectible    380269
# Other           94482
# Metaverse       41031
# Utility          8681
# Name: count, dtype: int64

# %% [markdown]
# ### Misc

# %%
opensea.isnull().sum()
# Out:
# Smart_contract                    0
# ID_token                          0
# Transaction_hash                  0
# Seller_address                    0
# Seller_username              814008
# Buyer_address                     0
# Buyer_username              1014399
# Image_url_1                    2917
# Image_url_2                   92526
# Image_url_3                    2834
# Image_url_4                    7446
# Price_Crypto                      0
# Crypto                            0
# Price_USD                      7935
# Name                          55319
# Description                  176540
# Collection                        0
# Market                            0
# Datetime_updated                  0
# Datetime_updated_seconds          0
# Permanent_link                    0
# Unique_id_collection              0
# Collection_cleaned                0
# Category                          0
# dtype: int64

# %%
opensea.describe()
# Out:
#        Price_Crypto     Price_USD
# count  1.907262e+06  1.899327e+06
# mean   1.825746e+03  4.189769e+02
# std    2.172536e+06  9.766780e+03
# min    0.000000e+00  2.264600e-16
# 25%    5.000000e-03  1.146930e+00
# 50%    3.298903e-02  1.372035e+01
# 75%    1.250000e-01  8.522910e+01
# max    3.000000e+09  7.501893e+06

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import networkx as nx

# %%
# Preprocessing
# Convert Datetime_updated_seconds from string to datetime, then to Unix timestamp (seconds)
opensea['Datetime_updated_seconds'] = pd.to_datetime(opensea['Datetime_updated_seconds'], errors='coerce')
opensea['Datetime_updated_seconds'] = (opensea['Datetime_updated_seconds'].astype('int64') // 10**9).astype('int64')  # Convert to seconds

# Create unique NFT identifier using Smart_contract and ID_token
opensea['NFT_ID'] = opensea['Smart_contract'] + '_' + opensea['ID_token']

# Handle missing Price_USD (7,935 missing as per your earlier note)
# Drop rows with missing Price_USD for simplicity; adjust if you have Price_Crypto conversion logic
opensea = opensea.dropna(subset=['Price_USD'])

# Ensure Seller_address and Buyer_address are strings
opensea['Seller_address'] = opensea['Seller_address'].astype(str)
opensea['Buyer_address'] = opensea['Buyer_address'].astype(str)

# Verify the conversion
print("Preprocessed Data Info:")
print(opensea.info())
print("\nSample Data:")
print(opensea[['NFT_ID', 'Seller_address', 'Buyer_address', 'Price_USD', 'Datetime_updated_seconds']].head())
print("\nVerification:")
print(f"Min Datetime_updated_seconds: {opensea['Datetime_updated_seconds'].min()}")
print(f"Datatype of Datetime_updated_seconds: {opensea['Datetime_updated_seconds'].dtype}")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\3497618860.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opensea['Datetime_updated_seconds'] = pd.to_datetime(opensea['Datetime_updated_seconds'], errors='coerce')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\3497618860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opensea['Datetime_updated_seconds'] = (opensea['Datetime_updated_seconds'].astype('int64') // 10**9).astype('int64')  # Convert to seconds
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\3497618860.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opensea['NFT_ID'] = opensea['Smart_contract'] + '_' + opensea['ID_token']
# Preprocessed Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1899327 entries, 4163765 to 6071026
# Data columns (total 25 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Smart_contract            object
#  1   ID_token                  object
#  2   Transaction_hash          object
#  3   Seller_address            object
#  4   Seller_username           object
#  5   Buyer_address             object
#  6   Buyer_username            object
#  7   Image_url_1               object
#  8   Image_url_2               object
#  9   Image_url_3               object
#  10  Image_url_4               object
#  11  Price_Crypto              float64
#  12  Crypto                    object
#  13  Price_USD                 float64
#  14  Name                      object
#  15  Description               object
#  16  Collection                object
#  17  Market                    object
#  18  Datetime_updated          object
#  19  Datetime_updated_seconds  int64
#  20  Permanent_link            object
#  21  Unique_id_collection      object
#  22  Collection_cleaned        object
#  23  Category                  object
#  24  NFT_ID                    object
# dtypes: float64(2), int64(1), object(22)
# memory usage: 376.8+ MB
# None
#
# Sample Data:
#                                                     NFT_ID  \
# 4163765  0x06012c8cf97bead5deae237070f9587f8e7a266d_570964
# 4163766  0x06012c8cf97bead5deae237070f9587f8e7a266d_553057
# 4163767  0x06012c8cf97bead5deae237070f9587f8e7a266d_422030
# 4163768  0x06012c8cf97bead5deae237070f9587f8e7a266d_551265
# 4163769  0x06012c8cf97bead5deae237070f9587f8e7a266d_561824
#
#                                      Seller_address  \
# 4163765  0xa21037849678af57f9865c6b9887f4e339f6377a
# 4163766  0x491677edd34020bf644fd63b5d65113fb3b74b10
# 4163767  0xe357cbc0a5dfa4c238b769d065416d15fb56d8f9
# 4163768  0xc4d4672f651bf72414be1f828952480ccf0b2a8f
# 4163769  0x7045540552d1fcc2ab1eb64e1f868aeb490606fa
#
#                                       Buyer_address   Price_USD  \
# 4163765  0x442dccee68425828c106a3662014b4f131e3bd9b  426.389768
# 4163766  0xf165d353abddb7cb00052d610254249fcc12a8c7   20.401690
# 4163767  0x24a6f141b18f27f65a1ba8b49e2d975d18e1a259   17.803485
# 4163768  0x5b897d015dbb2661e1fd4a0df68322dfaec6ea14   15.708933
# 4163769  0xb58092199e8b47bd9e27533d9504282eb802c446   65.981353
#
#          Datetime_updated_seconds
# 4163765                1519862490
# 4163766                1519862401
# 4163767                1519862359
# 4163768                1519862117
# 4163769                1519862047
#
# Verification:
# Min Datetime_updated_seconds: 1517726029
# Datatype of Datetime_updated_seconds: int64

# %%
def detect_nft_cycles(df, time_window_days=30, max_cycle_length=4):
    # Group transactions by NFT_ID
    nft_groups = df.groupby('NFT_ID')
    
    cycles = []
    for nft_id, group in nft_groups:
        G = nx.MultiDiGraph()
        # Add edges for this NFT
        for _, row in group.iterrows():
            G.add_edge(row['Seller_address'], row['Buyer_address'],
                       nft_id=nft_id, price=row['Price_USD'],
                       timestamp=row['Datetime_updated_seconds'])
        
        # Custom DFS to find cycles
        def dfs_cycle(node, start_node, path, visited, edges_used, max_timestamp):
            if len(path) > max_cycle_length:
                return
            if node == start_node and len(path) > 1:
                cycle_edges = []
                valid = True
                for i in range(len(path) - 1):
                    u, v = path[i], path[i + 1]
                    edge_data = G.get_edge_data(u, v, default={})
                    if not edge_data or max_timestamp - list(edge_data.values())[0]['timestamp'] > time_window_days * 86400:
                        valid = False
                        break
                    cycle_edges.append((u, v, list(edge_data.values())[0]))
                if valid:
                    cycles.append(cycle_edges)
                return
            
            for neighbor in G.neighbors(node):
                edge_key = (node, neighbor)
                if edge_key not in visited:
                    visited.add(edge_key)
                    path.append(neighbor)
                    dfs_cycle(neighbor, start_node, path, visited, edges_used, max_timestamp)
                    path.pop()
                    visited.remove(edge_key)
        
        max_ts = group['Datetime_updated_seconds'].max()
        for node in G.nodes():
            dfs_cycle(node, node, [node], set(), set(), max_ts)
    
    return cycles

# Apply to a subset for testing (e.g., first 1000 rows or specific collection)
subset = opensea.head(1000)  # Adjust as needed
cycles = detect_nft_cycles(subset)
print(f"Detected {len(cycles)} cycles in subset:")
for i, cycle in enumerate(cycles[:5]):  # Limit output
    print(f"Cycle {i + 1}: {cycle}")
# Out:
# Detected 0 cycles in subset:

# %%
subset = opensea.head(1000)
print("Subset Stats:")
print(f"Number of unique NFT_IDs: {subset['NFT_ID'].nunique()}")
print(f"Trades per NFT_ID:\n{subset['NFT_ID'].value_counts()}")
print(f"Unique Seller_addresses: {subset['Seller_address'].nunique()}")
print(f"Unique Buyer_addresses: {subset['Buyer_address'].nunique()}")
print(f"Timestamp range: {subset['Datetime_updated_seconds'].min()} to {subset['Datetime_updated_seconds'].max()}")
# Out:
# Subset Stats:
# Number of unique NFT_IDs: 1000
# Trades per NFT_ID:
# NFT_ID
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_570964    1
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_486373    1
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_562063    1
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_554671    1
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_564302    1
#                                                     ..
# 0x87d598064c736dd0c712d329afcfaa0ccc1921a1_1424      1
# 0x87d598064c736dd0c712d329afcfaa0ccc1921a1_1380      1
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_14728     1
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_5222      1
# 0x87d598064c736dd0c712d329afcfaa0ccc1921a1_1692      1
# Name: count, Length: 1000, dtype: int64
# Unique Seller_addresses: 319
# Unique Buyer_addresses: 326
# Timestamp range: 1519775866 to 1519862490

# %%
test_data = pd.DataFrame({
    'NFT_ID': ['test_1', 'test_1', 'test_1'],
    'Seller_address': ['0xa', '0xb', '0xa'],
    'Buyer_address': ['0xb', '0xa', '0xc'],
    'Price_USD': [100.0, 100.0, 100.0],
    'Datetime_updated_seconds': [1519862400, 1519862401, 1519862402]
})
cycles = detect_nft_cycles(test_data)
print(f"Detected {len(cycles)} cycles in test data:")
for i, cycle in enumerate(cycles):
    print(f"Cycle {i + 1}: {cycle}")
# Out:
# Detected 2 cycles in test data:
# Cycle 1: [('0xa', '0xb', {'nft_id': 'test_1', 'price': 100.0, 'timestamp': 1519862400}), ('0xb', '0xa', {'nft_id': 'test_1', 'price': 100.0, 'timestamp': 1519862401})]
# Cycle 2: [('0xb', '0xa', {'nft_id': 'test_1', 'price': 100.0, 'timestamp': 1519862401}), ('0xa', '0xb', {'nft_id': 'test_1', 'price': 100.0, 'timestamp': 1519862400})]

# %%
# Count trades per NFT_ID in the full dataset
nft_trade_counts = opensea['NFT_ID'].value_counts()
multi_trade_nfts = nft_trade_counts[nft_trade_counts > 1].index
print(f"Number of NFTs traded more than once: {len(multi_trade_nfts)}")
print(f"Top 5 multi-trade NFTs:\n{nft_trade_counts.head()}")

# Create a subset with only multi-trade NFTs
subset_multi = opensea[opensea['NFT_ID'].isin(multi_trade_nfts)].head(10000)  # Limit to 10k rows for speed
print(f"Subset size with multi-trade NFTs: {len(subset_multi)}")

# Run cycle detection
cycles = detect_nft_cycles(subset_multi)
print(f"Detected {len(cycles)} cycles in multi-trade subset:")
for i, cycle in enumerate(cycles[:5]):
    print(f"Cycle {i + 1}: {cycle}")
# Out:
# Number of NFTs traded more than once: 244177
# Top 5 multi-trade NFTs:
# NFT_ID
# 0x557430421f8f3ed0a92aca211f1c05ad7b606288_0                                                                                 5151
# 0x495f947276749ce646f68ac8c248420045cb7b5e_112375264289738882766071642401036387485470860384413915553824584745428864469444    1405
# 0xe4605d46fd0b3f8329d936a8b258d69276cba264_1                                                                                  796
# 0x5d00d312e171be5342067c09bae883f9bcb2003b_43995                                                                              711
# 0x06012c8cf97bead5deae237070f9587f8e7a266d_965763                                                                             703
# Name: count, dtype: int64
# Subset size with multi-trade NFTs: 10000
# Detected 6 cycles in multi-trade subset:
# Cycle 1: [('0xa110546519b9c6dfcebb58cd6a46859ac10abef0', '0x137d9174d3bd00f2153dcc0fe7af712d3876a71e', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_624315', 'price': 1.7167194704861108, 'timestamp': 1522247524}), ('0x137d9174d3bd00f2153dcc0fe7af712d3876a71e', '0xa110546519b9c6dfcebb58cd6a46859ac10abef0', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_624315', 'price': 12.676375, 'timestamp': 1521386226})]
# Cycle 2: [('0x137d9174d3bd00f2153dcc0fe7af712d3876a71e', '0xa110546519b9c6dfcebb58cd6a46859ac10abef0', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_624315', 'price': 12.676375, 'timestamp': 1521386226}), ('0xa110546519b9c6dfcebb58cd6a46859ac10abef0', '0x137d9174d3bd00f2153dcc0fe7af712d3876a71e', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_624315', 'price': 1.7167194704861108, 'timestamp': 1522247524})]
# Cycle 3: [('0x368195a0dffff950b98901a48429c14928446147', '0x6ce4895ad449ed24d640eea04507bc14ffcc408d', {'nft_id': '0xf7a6e15dfd5cdd9ef12711bd757a9b6021abf643_1990', 'price': 0.103665, 'timestamp': 1523860726}), ('0x6ce4895ad449ed24d640eea04507bc14ffcc408d', '0x368195a0dffff950b98901a48429c14928446147', {'nft_id': '0xf7a6e15dfd5cdd9ef12711bd757a9b6021abf643_1990', 'price': 0.060062, 'timestamp': 1524284474})]
# Cycle 4: [('0x6ce4895ad449ed24d640eea04507bc14ffcc408d', '0x368195a0dffff950b98901a48429c14928446147', {'nft_id': '0xf7a6e15dfd5cdd9ef12711bd757a9b6021abf643_1990', 'price': 0.060062, 'timestamp': 1524284474}), ('0x368195a0dffff950b98901a48429c14928446147', '0x6ce4895ad449ed24d640eea04507bc14ffcc408d', {'nft_id': '0xf7a6e15dfd5cdd9ef12711bd757a9b6021abf643_1990', 'price': 0.103665, 'timestamp': 1523860726})]
# Cycle 5: [('0x9c2fb48941ac6dbf58996d95d8d808b9dd0fa41f', '0x0cf6cdb4d406179f12a15797869ac6bd941c2535', {'nft_id': '0xf87e31492faf9a91b02ee0deaad50d51d56d5d4d_3743106036130323098097120681749450325891', 'price': 596.3939999999999, 'timestamp': 1548211555}), ('0x0cf6cdb4d406179f12a15797869ac6bd941c2535', '0x9c2fb48941ac6dbf58996d95d8d808b9dd0fa41f', {'nft_id': '0xf87e31492faf9a91b02ee0deaad50d51d56d5d4d_3743106036130323098097120681749450325891', 'price': 608.0880000000001, 'timestamp': 1548210109})]

# %% [markdown]
# 244,177 NFTs traded more than once: Out of ~1.9M rows, ~12.8% of unique NFTs (assuming most of the 1.9M rows are unique NFTs) are traded multiple times, which is a good pool for detecting cycles.
# Top NFTs: High trade counts (e.g., 5151 trades for one NFT) suggest potential hotspots for wash trading, especially if concentrated among a few addresses.
# Subset: 10,000 rows is a manageable size for testing and still captures multi-trade NFTs.

# %%
subset_multi_full = opensea[opensea['NFT_ID'].isin(multi_trade_nfts)]
print(f"Full multi-trade subset size: {len(subset_multi_full)}")
cycles_full = detect_nft_cycles(subset_multi_full)
print(f"Detected {len(cycles_full)} cycles in full multi-trade subset:")
for i, cycle in enumerate(cycles_full[:5]):
    print(f"Cycle {i + 1}: {cycle}")
# Out:
# Full multi-trade subset size: 710691
# Detected 2381 cycles in full multi-trade subset:
# Cycle 1: [('0x530cf036ed4fa58f7301a9c788c9806624cefd19', '0xab3009dbb3c9a5694ed818cf0d159e069dd55107', {'nft_id': '0x0111ac7e9425c891f935c4ce54cf16db7c14b7db_96', 'price': 1.36539, 'timestamp': 1553525841}), ('0xab3009dbb3c9a5694ed818cf0d159e069dd55107', '0x530cf036ed4fa58f7301a9c788c9806624cefd19', {'nft_id': '0x0111ac7e9425c891f935c4ce54cf16db7c14b7db_96', 'price': 9.831822, 'timestamp': 1553528716})]
# Cycle 2: [('0xab3009dbb3c9a5694ed818cf0d159e069dd55107', '0x530cf036ed4fa58f7301a9c788c9806624cefd19', {'nft_id': '0x0111ac7e9425c891f935c4ce54cf16db7c14b7db_96', 'price': 9.831822, 'timestamp': 1553528716}), ('0x530cf036ed4fa58f7301a9c788c9806624cefd19', '0xab3009dbb3c9a5694ed818cf0d159e069dd55107', {'nft_id': '0x0111ac7e9425c891f935c4ce54cf16db7c14b7db_96', 'price': 1.36539, 'timestamp': 1553525841})]
# Cycle 3: [('0xf8258c44c92cd8c6fc59f8cb8366b07c89579ca4', '0xf8258c44c92cd8c6fc59f8cb8366b07c89579ca4', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_1004112', 'price': 2.0874, 'timestamp': 1539755407})]
# Cycle 4: [('0xbabda06088c242fb2a763aa7cc99706cb77ba735', '0xe738725cdcc41c91f734dd7b5b9659df994d6dda', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_1009482', 'price': 63.69087499999999, 'timestamp': 1559086643}), ('0xe738725cdcc41c91f734dd7b5b9659df994d6dda', '0x1e7f320cf5a938465d501f6bd6c405feb3a70f6c', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_1009482', 'price': 90.580975, 'timestamp': 1561580547}), ('0x1e7f320cf5a938465d501f6bd6c405feb3a70f6c', '0xbabda06088c242fb2a763aa7cc99706cb77ba735', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_1009482', 'price': 71.821625, 'timestamp': 1559072644})]
# Cycle 5: [('0xbabda06088c242fb2a763aa7cc99706cb77ba735', '0x179d698f5a1c84c3ff4c5eb04e553c15a0c1d8d8', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_1009482', 'price': 65.564975, 'timestamp': 1559799203}), ('0x179d698f5a1c84c3ff4c5eb04e553c15a0c1d8d8', '0xbabda06088c242fb2a763aa7cc99706cb77ba735', {'nft_id': '0x06012c8cf97bead5deae237070f9587f8e7a266d_1009482', 'price': 65.281425, 'timestamp': 1560013037})]

# %%
cycles_df = pd.DataFrame([{
    'NFT_ID': cycle[0][2]['nft_id'],
    'Addresses': [edge[0] for edge in cycle] + [cycle[-1][1]],
    'Prices': [edge[2]['price'] for edge in cycle],
    'Timestamps': [edge[2]['timestamp'] for edge in cycle],
    'Volume_USD': sum(edge[2]['price'] for edge in cycle)
} for cycle in cycles_full])
cycles_df.to_csv('wash_trading_cycles.csv', index=False)
print(f"Total suspicious volume: ${cycles_df['Volume_USD'].sum():.2f}")
print(f"Average cycle length: {cycles_df['Addresses'].apply(len).mean():.2f}")
# Out:
# Total suspicious volume: $8423447.57
# Average cycle length: 3.25

# %% [markdown]
# - Detected 2,381 Cycles
#  - The detect_nft_cycles function found 2,381 instances where an NFT was traded in a closed loop (e.g., A → B → A or A → B → C → A) within a 30-day window, up to 4 nodes.
# Interpretation: This is strong evidence of potential wash trading, as these cycles suggest artificial activity where the NFT returns to its original owner or circulates among a small group. In the context of 710,691 rows, 2,381 cycles represent ~0.34% of transactions by count, but their economic impact (volume) is more telling.

# %% [markdown]
# - Total Suspicious Volume: $8,423,447.57
# - The sum of Price_USD across all 2,381 cycles is ~$8.42 million. This is the total economic value of these suspicious transactions.

# %% [markdown]
# - Average Cycle Length: 3.25
# - The mean number of trades (nodes) per cycle is 3.25, meaning most cycles are 2–4 trades long (e.g., A → B → A or A → B → C → A).
# - Interpretation: Short cycles (2–3 trades) are common in manual wash trading, as seen in von Wachter et al. (60.6% of cycles were 2-transaction). The 3.25 average aligns with a mix of simple back-and-forth trades and slightly longer loops

# %% [markdown]
# # Implications
#  - Wash Trading Confirmed: The presence of 2,381 cycles, including self-trades and rapid exchanges, matches the methodology’s criteria (self-trading, cyclic trading, rapid sequences). This supports the hypothesis that wash trading occurs in your OpenSea data.
# - Economic Impact: $8.42M in suspicious volume is significant, potentially inflating perceived market activity or prices for these NFTs.
# - Patterns: Self-trades (Cycle 3) and stable-price loops (Cycle 5) are textbook wash trading, while variable-price cycles (Cycle 1) might indicate more complex strategies.

# %%
cycles_df['Price_Variation'] = cycles_df['Prices'].apply(lambda x: (max(x) - min(x)) / min(x) if min(x) > 0 else float('inf'))
cycles_df['Time_Span'] = cycles_df['Timestamps'].apply(lambda x: max(x) - min(x))
print(f"Average price variation: {cycles_df['Price_Variation'].mean():.2f}")
print(f"Average time span (seconds): {cycles_df['Time_Span'].mean():.2f}")
# Out:
# Average price variation: 27.96
# Average time span (seconds): 551386.93

# %%
total_volume = opensea['Price_USD'].sum()
suspicious_pct = (cycles_df['Volume_USD'].sum() / total_volume) * 100
print(f"Total dataset volume: ${total_volume:.2f}")
print(f"Suspicious volume percentage: {suspicious_pct:.2f}%")
# Out:
# Total dataset volume: $795774046.42
# Suspicious volume percentage: 1.06%

# %%
print(cycles_df['Price_Variation'].describe())
print(f"Median price variation: {cycles_df['Price_Variation'].median():.2f}")
low_var_cycles = cycles_df[cycles_df['Price_Variation'] <= 0.05]
print(f"Cycles with <5% variation: {len(low_var_cycles)} (${low_var_cycles['Volume_USD'].sum():.2f})")
# Out:
# count     2381.000000
# mean        27.955872
# std        648.289551
# min          0.000000
# 25%          0.043478
# 50%          0.198780
# 75%          0.666667
# max      19999.000000
# Name: Price_Variation, dtype: float64
# Median price variation: 0.20
# Cycles with <5% variation: 637 ($2782705.95)

# %%
from collections import defaultdict
import networkx as nx  # Ensure this is also included

def detect_sccs(df, min_occurrences=50):
    suspicious_sccs = {}
    collection_groups = df.groupby('Smart_contract')
    
    for contract, group in collection_groups:
        G = nx.DiGraph()
        for _, row in group.iterrows():
            G.add_edge(row['Seller_address'], row['Buyer_address'])
        
        edge_counts = defaultdict(int)
        for u, v in G.edges():
            edge_counts[(u, v)] += 1
        
        G_simplified = nx.DiGraph()
        G_simplified.add_edges_from(edge_counts.keys())
        scc_counts = defaultdict(int)
        
        while G_simplified.edges():
            sccs = list(nx.strongly_connected_components(G_simplified))
            for scc in sccs:
                if len(scc) > 1:
                    scc_counts[frozenset(scc)] += 1
            edges_to_remove = []
            for u, v in G_simplified.edges():
                edge_counts[(u, v)] -= 1
                if edge_counts[(u, v)] == 0:
                    edges_to_remove.append((u, v))
            G_simplified.remove_edges_from(edges_to_remove)
        
        suspicious_sccs[contract] = {scc: count for scc, count in scc_counts.items() if count >= min_occurrences}
    
    return suspicious_sccs

# Now run the SCC detection
sccs = detect_sccs(subset_multi_full, min_occurrences=50)
print(f"Detected suspicious SCCs:")
for contract, scc_dict in sccs.items():
    print(f"Collection {contract}: {len(scc_dict)} SCCs")
    for scc, count in list(scc_dict.items())[:5]:
        print(f"  SCC {list(scc)}: {count} occurrences")
# Out:
# Detected suspicious SCCs:
# Collection 0x007810366aed6ed62af3240def95879c0f20b8c4: 0 SCCs
# Collection 0x0111ac7e9425c891f935c4ce54cf16db7c14b7db: 0 SCCs
# Collection 0x012408dd7d43a6b3949bdaa281c123b19652a0dc: 0 SCCs
# Collection 0x016cd7b70373a58a0e27051e089d7f02bfcd8127: 0 SCCs
# Collection 0x0181fd94dc8e5dd8ac71a74f0b27bdc68e99cc35: 0 SCCs
# Collection 0x0216eef69ce03ac91299eb039449a2bddc6ee8f5: 0 SCCs
# Collection 0x02c2ab0df26d287db71b9900629ebe2bc6aa7a8a: 0 SCCs
# Collection 0x02cb94aa04236904cabe656d2e70134e7388d342: 0 SCCs
# Collection 0x0333f63c8ed192ab07b70d67d18f787198c89fef: 0 SCCs
# Collection 0x0370905fefa8ce3ac068505c0b4de8db717cdb27: 0 SCCs
# Collection 0x0407812ebb0de83c20553aa1491fd159ee000c8c: 0 SCCs
# Collection 0x0427743df720801825a5c82e0582b1e915e0f750: 0 SCCs
# Collection 0x04f23ffaddddd335d3df6172d876e192fddd0eae: 0 SCCs
# Collection 0x0574c34385b039c2bb8db898f61b7767024a9449: 0 SCCs
# Collection 0x0593c32295d2a3848e873669ef0ec5d27d7360cc: 0 SCCs
# Collection 0x059edd72cd353df5106d2b9cc5ab83a52287ac3a: 0 SCCs
# Collection 0x06012c8cf97bead5deae237070f9587f8e7a266d: 0 SCCs
# Collection 0x067ab2fbdbed63401af802d1dd786e6d83b0ff1b: 0 SCCs
# Collection 0x068f74749c24a42058563035f8c786362fc96494: 0 SCCs
# Collection 0x06a6a7af298129e3a2ab396c9c06f91d3c54aba8: 0 SCCs
# Collection 0x0733411463d71e33a41c73b63367389b886c1d12: 0 SCCs
# Collection 0x0756c900b18dd0c945b62685f8ca57c8a11ab025: 0 SCCs
# Collection 0x0760abbcade5fe056bbd79a625ca2e18c17dc0e8: 0 SCCs
# Collection 0x079b18d6556e198c98e599490c6cbba231ab4db8: 0 SCCs
# Collection 0x07ccfd0fbada4ac3c22ecd38037ca5e5c0ad8cfa: 0 SCCs
# Collection 0x08170dbe6762100d4852f276915afe179da14998: 0 SCCs
# Collection 0x082903f4e94c5e10a2b116a4284940a36afaed63: 0 SCCs
# Collection 0x083775fdfcf0cb4780efe9710801d082005b55ea: 0 SCCs
# Collection 0x08d0de44c61634775c2238197a28ee20b6cd5d5e: 0 SCCs
# Collection 0x08d5a6a6b01cbcba2b90eb22bac81637020923f0: 0 SCCs
# Collection 0x090c53bac270768759c8f4c93151bd1a808a280e: 0 SCCs
# Collection 0x094634cf5ec4b34b7f47bcb2c03c1c9f48e1ece8: 0 SCCs
# Collection 0x09b9905a472aa1d387c9c1d8d956aff5463837e8: 0 SCCs
# Collection 0x0b509f4b044f713a91bb50535914f7ad160532fe: 0 SCCs
# Collection 0x0c6644c9973593b6a4c9c0af1af88f6b29ecace9: 0 SCCs
# Collection 0x0c69326bea87398a12be5d3224bd37ac64b30b76: 0 SCCs
# Collection 0x0cbd0570401aa68f9e4fee05285eacd7b1bb6069: 0 SCCs
# Collection 0x0ce87f77b1d83df522ae96af9cf810b16ab0942b: 0 SCCs
# Collection 0x0cf674e50aded42d405e1fd750f3998d8f9a033b: 0 SCCs
# Collection 0x0cf74f8414db9db05fc940adbb7b6a02a693365d: 0 SCCs
# Collection 0x0d0b764662a30078f0571c1da3f597fe2ad50622: 0 SCCs
# Collection 0x0d8c864da1985525e0af0acbeef6562881827bd5: 0 SCCs
# Collection 0x0daaa0d0b75e4c0572a57e7f1f7692e20f3ed7c8: 0 SCCs
# Collection 0x0e3a2a1f2146d86a604adc220b4967a898d7fe07: 0 SCCs
# Collection 0x0e49144b8b8d228eb7d266f15b2e140fea72a54e: 0 SCCs
# Collection 0x0e758eeb09e047cd0eb1650859065e2e07b1ecc4: 0 SCCs
# Collection 0x0e92164df9bc46855c9476384abc4e8fd2c47edc: 0 SCCs
# Collection 0x0eed7d6564fae0c22a7dc9ebb3db4a4c4a1473ee: 0 SCCs
# Collection 0x0eefb8cf8128019b1609fbab1b5a5afb757863f6: 0 SCCs
# Collection 0x0f0ea6ceb2eb0460225cd2c18aa4e6c37ca23de3: 0 SCCs
# Collection 0x0f384a08719ab48fec3f2e2ab8c1420e9d214566: 0 SCCs
# Collection 0x0f3b491841680eb40bd2be42bce7104f2511dbd9: 0 SCCs
# Collection 0x0f4b33fdc45581fa98839c8cef6ed79437eb6363: 0 SCCs
# Collection 0x10319d7994f211297de6ae555013a3eec23b9511: 0 SCCs
# Collection 0x10a7ecf97c46e3229fe1b801a5943153762e0cf0: 0 SCCs
# Collection 0x112bec51a4b0942e7f7b2a5090f5ad57b7901559: 0 SCCs
# Collection 0x118ac664ae5595562e2405b1788267c87f52c549: 0 SCCs
# Collection 0x11e246c34707f7b1d0ce7170026090630274d31a: 0 SCCs
# Collection 0x12166e8ab10d66f1f1d01cbb6ed0d2246f990d8e: 0 SCCs
# Collection 0x121a03f7b2427cc5546f4c9bf6f2dd43a36b3d01: 0 SCCs
# Collection 0x12419eea0b053ffea92f9afcd7986a495e2cf0dd: 0 SCCs
# Collection 0x125cb8f8c39116fed1b51c885848fda08c0b7542: 0 SCCs
# Collection 0x1276dce965ada590e42d62b3953ddc1ddceb0392: 0 SCCs
# Collection 0x12d46d45a7762df53e8c92e43b48ae40e1541f68: 0 SCCs
# Collection 0x12f28e2106ce8fd8464885b80ea865e98b465149: 0 SCCs
# Collection 0x12f49eda69adaba6b857988bb22ca420d991ebb7: 0 SCCs
# Collection 0x1301566b3cb584e550a02d09562041ddc4989b91: 0 SCCs
# Collection 0x13bab10a88fc5f6c77b87878d71c9f1707d2688a: 0 SCCs
# Collection 0x1496640fc4bdfd7ee6361894f5eefe1f5f297c6d: 0 SCCs
# Collection 0x14c4293d7e7325cec8c52cea3df37d91aa9cc7b6: 0 SCCs
# Collection 0x14e8640d94a9910fe650c5a1b8ee271b505ce4cc: 0 SCCs
# Collection 0x151ea7a71594e19b4d08c2ba45600963485cd3c2: 0 SCCs
# Collection 0x155cbbca1ab35eab09b66270046317803919e555: 0 SCCs
# Collection 0x157ad40f43e26e72909f16bb07f2ca97466df849: 0 SCCs
# Collection 0x15820072729d045ec5232ba3bd060ec5df38e09a: 0 SCCs
# Collection 0x15b4843d34ce5eea62b3993a6fb761fd04aa9f45: 0 SCCs
# Collection 0x1651bd62a6ae8c43bdba7c3c6c344c3079936071: 0 SCCs
# Collection 0x165a7cbb4c0f88c2ad40efe141ead10706ae5f37: 0 SCCs
# Collection 0x166c740d4f42dafa1037b12ad4378a20f246006c: 0 SCCs
# Collection 0x16ac942e7c194051651cac878c3ca363ba2ab948: 0 SCCs
# Collection 0x16b9805a107d0c2803d1f995f68379b975a970d2: 0 SCCs
# Collection 0x1702bea2755d076adf737b785926b086eff36f75: 0 SCCs
# Collection 0x17571820e22c0f4773ec36147737720b0f047a60: 0 SCCs
# Collection 0x17acddb7053be19e852e64dc5a344b599756f557: 0 SCCs
# Collection 0x181aea6936b407514ebfc0754a37704eb8d98f91: 0 SCCs
# Collection 0x183dac7e644964a1605ca06c9d1ec8e84f36847a: 0 SCCs
# Collection 0x1843d7696373fd543c3673e3cde6119c9d1bd295: 0 SCCs
# Collection 0x185f74df3e8c5f2a9fb7b3ec5e90494b91b6ca4e: 0 SCCs
# Collection 0x1986f4c2e3ad5fe9778da67b1b836cf53b9e20cd: 0 SCCs
# Collection 0x1a2ef5e538a6c2ae214a5fe2684af7eca05fa17a: 0 SCCs
# Collection 0x1a94fce7ef36bc90959e206ba569a12afbc91ca1: 0 SCCs
# Collection 0x1bc0c6d164e9e7b3e8e357baebb24994cf84f85d: 0 SCCs
# Collection 0x1ca3262009b21f944e6b92a2a88d039d06f1acfa: 0 SCCs
# Collection 0x1ccf0477a5562b7e14862d13b7daa389577a2be2: 0 SCCs
# Collection 0x1ce7a600ed98dd51e3d7580e4c707cfcf896efac: 0 SCCs
# Collection 0x1d963688fe2209a98db35c67a041524822cf04ff: 0 SCCs
# Collection 0x1db61fc42a843bad4d91a2d788789ea4055b8613: 0 SCCs
# Collection 0x1dd2c47496fbd9d38ac9a884d15d816b062e1f6e: 0 SCCs
# Collection 0x1e1b3525388e8a63988f8455638aee87f68eeaa7: 0 SCCs
# Collection 0x1e1d4e6262787c8a8783a37fee698bd42aa42bec: 0 SCCs
# Collection 0x1eac31a0b93e81bd093d116f5d36a83be08f381b: 0 SCCs
# Collection 0x1eef8e428c8148af2b05c083d5f275eaa05f1268: 0 SCCs
# Collection 0x1f42f3e36f8c61fcbef35e0cfb88bdf9392856ed: 0 SCCs
# Collection 0x1fc4336d4b3aa163ca855d45555207fddb70f719: 0 SCCs
# Collection 0x20172dab13e0cf9465382b32fe46cd51247cad71: 0 SCCs
# Collection 0x20bd491fee75b6af6c2100c83b83312d620f2958: 0 SCCs
# Collection 0x20c9a5adf56f530ea60f2609851d8848886993a2: 0 SCCs
# Collection 0x20d4cec36528e1c4563c1bfbe3de06aba70b22b4: 0 SCCs
# Collection 0x20eecec5530e772f17f8b37dbfbcce4a67e4fbe8: 0 SCCs
# Collection 0x21e6348da1793ce4700180ba56c627cea756f5c9: 0 SCCs
# Collection 0x2202751e546665c4e6456d1ba27db4f246004063: 0 SCCs
# Collection 0x221572fcd696c8d554a52ec38687cafca03e0b03: 0 SCCs
# Collection 0x2216d47494e516d8206b70fca8585820ed3c4946: 0 SCCs
# Collection 0x2250d7c238392f4b575bb26c672afe45f0adcb75: 0 SCCs
# Collection 0x229d2a2cecae97a45fa3a9cbfd0297c22d3270b3: 0 SCCs
# Collection 0x22a40a30b5e581f5bdc6afea7afedb3fa735d9d9: 0 SCCs
# Collection 0x22adcaf1d6b5213a76bfddab6d4d38c25ce7c029: 0 SCCs
# Collection 0x22c1f6050e56d2876009903609a2cc3fef83b415: 0 SCCs
# Collection 0x22d31a97da148476aa2b76d63ef2f20b53f7ab4e: 0 SCCs
# Collection 0x2374425c7e7ddf1d46f771f068d205aed551faf8: 0 SCCs
# Collection 0x23766996636058b41a041d441ce1217c694f5aa9: 0 SCCs
# Collection 0x238f2d6787dacb6045d72b0ec6626de0ff7c3107: 0 SCCs
# Collection 0x23b608675a2b2fb1890d3abbd85c5775c51691d5: 0 SCCs
# Collection 0x23cd7da31501aa54f61384a3756fb4a1329dbb2c: 0 SCCs
# Collection 0x247c1386e2191d4180d524c4b11f62bfbef9838a: 0 SCCs
# Collection 0x24c3124dc5200e5bfaa5cf4755ad4cc591c65ee2: 0 SCCs
# Collection 0x25271fad43f59614c0928f63e0e7e10c2b280e89: 0 SCCs
# Collection 0x25741f5f2dbdde9cfd38f73be7052ec03b0e9d85: 0 SCCs
# Collection 0x2594d80da5f2e4f742d1e479eb9408aad132d0bd: 0 SCCs
# Collection 0x25c0d8402e55f49afa65a121fe421ba92e1981bd: 0 SCCs
# Collection 0x26400bde3ecf7f6ce42815ee435b857b363f514d: 0 SCCs
# Collection 0x26acd85ac57687220b7b4a0bf6bc44ab7c919a49: 0 SCCs
# Collection 0x26b365dd6c6c2c5c1b19658ede5ef00c12402702: 0 SCCs
# Collection 0x26e1311ca72e622eabee7c02f6c48564726eaf0d: 0 SCCs
# Collection 0x271a0b465d5b453bb835afd2d671c76b2b76900e: 0 SCCs
# Collection 0x273f7f8e6489682df756151f5525576e322d51a3: 0 SCCs
# Collection 0x274e21d314a915d1504060d4351dde05d4dc031e: 0 SCCs
# Collection 0x27b4bc90fbe56f02ef50f2e2f79d7813aa8941a7: 0 SCCs
# Collection 0x27bab5db0f14590feaed4bf00798dadab90f2fcd: 0 SCCs
# Collection 0x280afd45d12103fed9effb9e8b045e5aaca0a97b: 0 SCCs
# Collection 0x287e3775ed91ed661b6806eeebdee91e5710a2f3: 0 SCCs
# Collection 0x28a8874150ccdb519ce06adc584961a14fe3b186: 0 SCCs
# Collection 0x28e2d5d0f53072eecd56e0f2c574ab30338664fb: 0 SCCs
# Collection 0x291c9486d3f664d78e72ebb6cbf20428f9e5a907: 0 SCCs
# Collection 0x2998d346c66259e3e73dd7410899948371a28e94: 0 SCCs
# Collection 0x29d67a0a6e8a4ff5ce9afbd9da1b87e587bc76be: 0 SCCs
# Collection 0x29e9853b325945ca64da906c81b895ebb9b7f427: 0 SCCs
# Collection 0x2a187453064356c898cae034eaed119e1663acb8: 0 SCCs
# Collection 0x2a378c8d96e7d994fb9bec6adb7c6af2fe772c3b: 0 SCCs
# Collection 0x2a46f2ffd99e19a89476e2f62270e0a35bbf0756: 0 SCCs
# Collection 0x2a6e931c1bf12ea508402f1faf86c4c4c08aad18: 0 SCCs
# Collection 0x2aea4add166ebf38b63d09a75de1a7b94aa24163: 0 SCCs
# Collection 0x2aeaffc99cef9f6fc0869c1f16f890abdfcc222b: 0 SCCs
# Collection 0x2af75676692817d85121353f0d6e8e9ae6ad5576: 0 SCCs
# Collection 0x2b4572419f2b2a0c198cc8789de881287c09d8c3: 0 SCCs
# Collection 0x2b534cdd43d6eb1567be24f3cf7304da3dcd792a: 0 SCCs
# Collection 0x2c04e6dd23c33a66f58dfb79dfb15285336c92d0: 0 SCCs
# Collection 0x2d6aff6ffffb60f5fdaf5a0ef4c1096644270d37: 0 SCCs
# Collection 0x2d6e10561b320c4f31a903bf0fa92a1ed58637c0: 0 SCCs
# Collection 0x2d9e5de7d36f3830c010a28b29b3bdf5ca73198e: 0 SCCs
# Collection 0x2e472c8c7f9659f5b61d83f547c90ea8b8247df0: 0 SCCs
# Collection 0x2e734269c869bda3ea6550f510d2514f2d66de71: 0 SCCs
# Collection 0x2e7a5458cc822409e459f23cfb9209c0cd077d69: 0 SCCs
# Collection 0x2eeae71d1a38d5d89aafdce6ed43b11ce63a5e71: 0 SCCs
# Collection 0x2f1d835fdc8b59e03828d9b7f0b91b046b40f5bc: 0 SCCs
# Collection 0x2f2d5aa0efdb9ca3c9bb789693d06bebea88792f: 0 SCCs
# Collection 0x2f4bdafb22bd92aa7b7552d270376de8edccbc1e: 0 SCCs
# Collection 0x2f5dca0ae3306b35cce02311ff70a716f184ddfb: 0 SCCs
# Collection 0x2fb5d7dda4f1f20f974a0fdd547c38674e8d940c: 0 SCCs
# Collection 0x300533115a586fa305fe6ca4a32fb22c22abbd92: 0 SCCs
# Collection 0x3037e5a90942d37d5c57c23eef2d262dd146765a: 0 SCCs
# Collection 0x3045474044a37d59d117200b7577af6532b80043: 0 SCCs
# Collection 0x3068b3313281f63536042d24562896d080844c95: 0 SCCs
# Collection 0x30a2fa3c93fb9f93d1efeffd350c6a6bb62ba000: 0 SCCs
# Collection 0x30ab12b93a31124333643cb6d55b96046b31aaa1: 0 SCCs
# Collection 0x30d3387ff3de2a21bef7032f82d00ff7739e403c: 0 SCCs
# Collection 0x31385d3520bced94f77aae104b406994d8f2168c: 0 SCCs
# Collection 0x31865d76403511000d44c803017f71f6d4bc02e6: 0 SCCs
# Collection 0x318bfbb5dfae7ee7c853eb82dbab9e10a45e768d: 0 SCCs
# Collection 0x31af195db332bc9203d758c74df5a5c5e597cdb7: 0 SCCs
# Collection 0x31fe290644df7aef49274ae4b11ffdcc4e83f3cd: 0 SCCs
# Collection 0x3216502ccf3cbe147ed3d75d44e9adf6e8054806: 0 SCCs
# Collection 0x32aa0094c6766c04e0e8bb4d14033d5904862545: 0 SCCs
# Collection 0x32b7495895264ac9d0b12d32afd435453458b1c6: 0 SCCs
# Collection 0x32fcff64d426d017deec541557bec47358be53f2: 0 SCCs
# Collection 0x336dcf0f4c0d6465f0cf6445f89da6007ccd186d: 0 SCCs
# Collection 0x337c0be4fb4238c9fc75a2e20ad4367a79318db9: 0 SCCs
# Collection 0x33859e4c083544e506712984b81ea3f3b551bc16: 0 SCCs
# Collection 0x33a4cfc925ad40e5bb2b9b2462d7a1a5a5da4476: 0 SCCs
# Collection 0x33b83b6d3179dcb4094c685c2418cab06372ed89: 0 SCCs
# Collection 0x33c8a345830636556160c2ebc3abb90be2e1252b: 0 SCCs
# Collection 0x34037a293ffb6e29057ea7f36a453a39dccd130a: 0 SCCs
# Collection 0x3427b2b238fd94a5cce545437fc66c6bd6e414dc: 0 SCCs
# Collection 0x347a4c79bc0dcc6077a9d5e7b81fb1da2479f60a: 0 SCCs
# Collection 0x3537fe1a01f684fb0b78d41f8945f01105180307: 0 SCCs
# Collection 0x35857182ed7400c2b0f780e8a929b6e97d362ac9: 0 SCCs
# Collection 0x35a397b958691f6f27d2f7eb0138a3fd4556393a: 0 SCCs
# Collection 0x35b7838dd7507ada69610397a85310ae0abd5034: 0 SCCs
# Collection 0x35f7319878556806e9f5b66f9d3b4506c16d3bbb: 0 SCCs
# Collection 0x362219d2a3a5491100d673fc899dde507c5d5534: 0 SCCs
# Collection 0x36ba769a5dad72a7a1add8a4b22eb407093b5f8d: 0 SCCs
# Collection 0x36bcede9b5a1328a8912b63389604ff451fa5a8e: 0 SCCs
# Collection 0x36d16e0758d1b52c28c4579e12b9efa0d23bab29: 0 SCCs
# Collection 0x36f379400de6c6bcdf4408b282f8b685c56adc60: 0 SCCs
# Collection 0x375348350bcee1cf3e4b494eea18236c87915f0b: 0 SCCs
# Collection 0x380aceb3b976d7e724ed3ccf05309a30b99d48ab: 0 SCCs
# Collection 0x38da695c837bb0ee4aa9f62be0307f3d94003c4b: 0 SCCs
# Collection 0x38e908b70c8e0dcfe452c0fb2ebf432f9c5a6f20: 0 SCCs
# Collection 0x3910d4afdf276a0dc8af632ccfceccf5ba04a3b7: 0 SCCs
# Collection 0x39fd485dccd38b6189a7b66c707b717f3e99bd96: 0 SCCs
# Collection 0x3a0c25422d086950880a976557d53d924935d878: 0 SCCs
# Collection 0x3a3b0dbdc0f6bc77421dcd2f55cfa087b0db9aec: 0 SCCs
# Collection 0x3a6504feb012cdff702019dd1f03d8cf99c029d9: 0 SCCs
# Collection 0x3b05f81864c943590c3364e5fe06632dc531cc1c: 0 SCCs
# Collection 0x3b3ee1931dc30c1957379fac9aba94d1c48a5405: 0 SCCs
# Collection 0x3b94eb47e44e397124c5e87103839c8eac0c1f5b: 0 SCCs
# Collection 0x3c230084fef56a4d8cfd8c89d8ebc67a8e4bde47: 0 SCCs
# Collection 0x3c2754c0cdc5499df1a50d608d8985070bf87b30: 0 SCCs
# Collection 0x3cd41ec039c1f2dd1f76144bb3722e7b503f50ab: 0 SCCs
# Collection 0x3d0c4e9bde15f2681902f9f291b3c905b7ea46f9: 0 SCCs
# Collection 0x3d9b128ce781a4a9c1057f785d97131a6357ca38: 0 SCCs
# Collection 0x3e3bf91740a8363d9433c8d3535b9b3c9e55f669: 0 SCCs
# Collection 0x3ec057be60db3a2d416e14a6e3ab7f37ffccd7b8: 0 SCCs
# Collection 0x3edf71a31b80ff6a45fdb0858ec54de98df047aa: 0 SCCs
# Collection 0x3eea5bf894236f4b7a6f1451bca89a9c91f49719: 0 SCCs
# Collection 0x3f133816f8178b93ac991a2c3eeddb8f947af0cb: 0 SCCs
# Collection 0x3f4a759e9a11f109c7970cef934d6753c1a5c43e: 0 SCCs
# Collection 0x3fa2bc8c8aa9e2706c3b5c17359a104aa412e3cc: 0 SCCs
# Collection 0x401b3474a0a2fbcb00d516c1ffc01854b9d9dafe: 0 SCCs
# Collection 0x40b897e287e633da94a74e2adabdcbdacffd0eba: 0 SCCs
# Collection 0x40f14fadea10daab99214368dcde893300ecdbce: 0 SCCs
# Collection 0x41113bce4659cb4912ed61d48154839f75131d7a: 0 SCCs
# Collection 0x417cf58dc18edd17025689d13af2b85f403e130c: 0 SCCs
# Collection 0x41a322b28d0ff354040e2cbc676f0320d8c8850d: 0 SCCs
# Collection 0x41b459f1f57f8b043a5926e9b15446adf4f1110e: 0 SCCs
# Collection 0x4222b2a98daa443c6a0a761300d7d6bfd9161e52: 0 SCCs
# Collection 0x4243a8413a77eb559c6f8eaffa63f46019056d08: 0 SCCs
# Collection 0x424db67b40b15ed85475c3f29dedf601b6ee75b2: 0 SCCs
# Collection 0x42b4a7db1ed930198bc37971b33e86f19ce88600: 0 SCCs
# Collection 0x42ea135d8e9e90657d6d5f715f59794c68be7f17: 0 SCCs
# Collection 0x43405d800766dc6ecafcc4d4d86d1b1463f556f0: 0 SCCs
# Collection 0x435c8739d1fd6d2a29ab1dcc667a2e4a360e3ed4: 0 SCCs
# Collection 0x440116abd7338d9ccfdc8b9b034f5d726f615f6d: 0 SCCs
# Collection 0x443b862d3815b1898e85085cafca57fc4335a1be: 0 SCCs
# Collection 0x448577972f709c1751da5bfef4c9486671baec4c: 0 SCCs
# Collection 0x448cb15b00ced3ac47467e33493d602f34c8e77e: 0 SCCs
# Collection 0x44d6e8933f8271abcf253c72f9ed7e0e4c0323b3: 0 SCCs
# Collection 0x45030cf1d09724dff48b54e88ecb6a1bfbdf651b: 0 SCCs
# Collection 0x452b2bc7c94515720b36d304ce33909a8323f3e3: 0 SCCs
# Collection 0x45301a18cab92399cf67c5ffece51e5cbbafb1cc: 0 SCCs
# Collection 0x45503d36827227f0d110fb3a17b4e1bbdf5c44d8: 0 SCCs
# Collection 0x455f9e7020a0b1fe5cbdebb11d5e3ec2c585fe36: 0 SCCs
# Collection 0x4568c3a9d7622d8eec6da47029325d54222b7028: 0 SCCs
# Collection 0x4690b1efab2ea1232fb95a89e175abd3331b0f62: 0 SCCs
# Collection 0x46caa8e7907cf10158dc50d609e23548c812c33a: 0 SCCs
# Collection 0x46cec00d100b63b6447d3475f27894aa16894966: 0 SCCs
# Collection 0x46f9a4522666d2476a5f5cd51ea3e0b5800e7f98: 0 SCCs
# Collection 0x4753a1cbdd4b03df356aae7304a0e4232e6e20f2: 0 SCCs
# Collection 0x478059f577cb739f0af0f37a365dd069ba5bd8be: 0 SCCs
# Collection 0x47dd306909fcd7cd22dfbf2548f7e43a8594b243: 0 SCCs
# Collection 0x47dd5f6335ffecbe77e982d8a449263d1e501301: 0 SCCs
# Collection 0x480a0f4e360e8964e68858dd231c2922f1df45ef: 0 SCCs
# Collection 0x4813c06eb9919db20634c431565d6b88f35501ff: 0 SCCs
# Collection 0x48d97463a455c39d8149fdd73ac5b7fc8a5ec3b1: 0 SCCs
# Collection 0x4928466e7a766c3c40ea5d41deb4f1c8ff7a32ab: 0 SCCs
# Collection 0x492c04144cd934eb918464426fbeb415e41ff7a7: 0 SCCs
# Collection 0x492c0d0a51cbf9dc225a485f9c722413615fc570: 0 SCCs
# Collection 0x495f947276749ce646f68ac8c248420045cb7b5e: 0 SCCs
# Collection 0x49c358afee381d32582700cbdd7e9746dc341973: 0 SCCs
# Collection 0x49d784562e790179d3630dfa0faea9e59fee5b61: 0 SCCs
# Collection 0x4ad4455ad5ef891695c221e8e683efa65fabede0: 0 SCCs
# Collection 0x4ae57798aef4af99ed03818f83d2d8aca89952c7: 0 SCCs
# Collection 0x4baf72c20f7a345f62d5795ad4fd80bba42a2f50: 0 SCCs
# Collection 0x4c9c971fbefc93e0900988383dc050632deec71e: 0 SCCs
# Collection 0x4c9e324fd7df8b2a969969bcc3663d74f058d286: 0 SCCs
# Collection 0x4c9ec01dd6d04971b7ba046af023fb8a9c92594b: 0 SCCs
# Collection 0x4c9f1b0313699ce67264bac7326a7a02ebee747a: 0 SCCs
# Collection 0x4caaf4e5c5132b3f532749255541ea5c33bb61c4: 0 SCCs
# Collection 0x4d36e460f9fd391f115676d997e5187edcc8404f: 0 SCCs
# Collection 0x4d3814d4da8083b41861dec2f45b4840e8b72d68: 0 SCCs
# Collection 0x4d7fe227faa08f0307bcb5fb0f6ce8703c8d1d11: 0 SCCs
# Collection 0x4df5675f9a5996b292a8704bc467c684f66eda58: 0 SCCs
# Collection 0x4e302fc5aac305b6976c1d837f3114bf76e7b8a5: 0 SCCs
# Collection 0x4eb3a5f2458bdf2edd180e5af1cb4b71872539e6: 0 SCCs
# Collection 0x4ebeae4abae85024a0e6b8b209ea8e1c6d3adb4a: 0 SCCs
# Collection 0x4ee2513dc4e4b3999ca4f79566b1f8f66f64fd93: 0 SCCs
# Collection 0x4f41d10f7e67fd16bde916b4a6dc3dd101c57394: 0 SCCs
# Collection 0x4fe99deb8f0be517c31faaad49b4b054ed28c267: 0 SCCs
# Collection 0x4fece400c0d3db0937162ab44bab34445626ecfe: 0 SCCs
# Collection 0x505df5ace201098b1d198aad048cb61c9f0246d4: 0 SCCs
# Collection 0x50f5474724e0ee42d9a4e711ccfb275809fd6d4a: 0 SCCs
# Collection 0x5111c8103776e097c7114282c9e0ff7acba16095: 0 SCCs
# Collection 0x51e613727fdd2e0b91b51c3e5427e9440a7957e4: 0 SCCs
# Collection 0x52093bcc26025537596688a5dc074e05c3c72a7b: 0 SCCs
# Collection 0x5237e33d805339925aa5ab220f13b386357aa349: 0 SCCs
# Collection 0x5283fc3a1aac4dac6b9581d3ab65f4ee2f3de7dc: 0 SCCs
# Collection 0x52b68a835aca64262845ccad4e18d58e10f0f521: 0 SCCs
# Collection 0x5351105753bdbc3baa908a0c04f1468535749c3d: 0 SCCs
# Collection 0x537eb102e8a97c1c3a623da6d3d03171dd8cf6d6: 0 SCCs
# Collection 0x53e3169046a25d7d67d163a1d46156f4c1955834: 0 SCCs
# Collection 0x543ecfb0d28fa40d639494957e7cba52460f490e: 0 SCCs
# Collection 0x5470bad79b5f80149bed3cd2676e3ddcc4730334: 0 SCCs
# Collection 0x552d72f86f04098a4eaeda6d7b665ac12f846ad2: 0 SCCs
# Collection 0x55591531864a6f0788387b00a8ad98032ad9ac79: 0 SCCs
# Collection 0x557430421f8f3ed0a92aca211f1c05ad7b606288: 0 SCCs
# Collection 0x55a2525a0f4b0caa2005fb83a3aa3ac95683c661: 0 SCCs
# Collection 0x55a7a2f764a86b4622510af16006c8017cdd76db: 0 SCCs
# Collection 0x56074ac10eef4c63428e0be4853e5bcfebd42bd0: 0 SCCs
# Collection 0x5694bce5b6f06dcd69028d40ab856efc295a524b: 0 SCCs
# Collection 0x56b24ac7d1060d67785d8c9dddf74d86953f81e5: 0 SCCs
# Collection 0x56e81e9cbd38bcf72cb3f5a976ab2a5d96cb0d0b: 0 SCCs
# Collection 0x56f123785b54978c6c0b117f15d3ee69eb9bf6c8: 0 SCCs
# Collection 0x574317b5167521d2e3e34469a6993102fbbd92ed: 0 SCCs
# Collection 0x574f64ac2e7215cba9752b85fc73030f35166bc0: 0 SCCs
# Collection 0x57a204aa1042f6e66dd7730813f4024114d74f37: 0 SCCs
# Collection 0x57a39b53e3e90d0820d1448fa0920b2355773b0f: 0 SCCs
# Collection 0x57cdee8a9658f364553fe89ba200252b00ad05d9: 0 SCCs
# Collection 0x57e9a39ae8ec404c08f88740a9e6e306f50c937f: 0 SCCs
# Collection 0x57f0b53926dd62f2e26bc40b30140abea474da94: 0 SCCs
# Collection 0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85: 0 SCCs
# Collection 0x588c5aee9bac620b4435435903c01223a9989abc: 0 SCCs
# Collection 0x58ac02a37dafbb0ea06f5d1590ac450713a417c6: 0 SCCs
# Collection 0x5924cd4764df7a1b12c725c05fca70bd510f4689: 0 SCCs
# Collection 0x59516426a8bb328d2f546b05421cbc047042e38f: 0 SCCs
# Collection 0x595f279de4b5df1e47ca55b65175d8a9a935a0fa: 0 SCCs
# Collection 0x5ad40fc0546f9d90dd0f46cf04457b652029152b: 0 SCCs
# Collection 0x5b0e580c6e44162ca8e3e3b59e7fe97a83ea1fcd: 0 SCCs
# Collection 0x5b50931305b4ae11c08876431f0baeb51d8a6daa: 0 SCCs
# Collection 0x5b52014d73e0c8c0eb0ad3720fc159d054790223: 0 SCCs
# Collection 0x5b8b553370703d7edc894da4332a41025f3b86f2: 0 SCCs
# Collection 0x5bb3d01f32687f92f8636799687e55cba0627704: 0 SCCs
# Collection 0x5bbef39747422e21991f5c8dc7e8b0c938c9970a: 0 SCCs
# Collection 0x5c1110907a0f0d39b7e3b7bf472981bc19e88a62: 0 SCCs
# Collection 0x5c1749bc5734b8f9ea7cda7e38b47432c6cffb66: 0 SCCs
# Collection 0x5c6e2892ed14bd178f0928abce94c1373b8265eb: 0 SCCs
# Collection 0x5caebd3b32e210e85ce3e9d51638b9c445481567: 0 SCCs
# Collection 0x5ce81c3c55de63cc9893361900d6c849b5382bb5: 0 SCCs
# Collection 0x5ceb7e1bd70690667b19bd2832ca85aef221a79a: 0 SCCs
# Collection 0x5d00d312e171be5342067c09bae883f9bcb2003b: 0 SCCs
# Collection 0x5d0ee539893323f9965e3ac2846ea6421255ae79: 0 SCCs
# Collection 0x5dea989fef70b042d47d09ff3138dacc22b2c5fc: 0 SCCs
# Collection 0x5e30b1d6f920364c847512e2528efdadf72a97a9: 0 SCCs
# Collection 0x5e876afe2ad4a21cd895395c0cc2fb8a8b2105e4: 0 SCCs
# Collection 0x5ee0900fa78dc40279cc7372884f1a2ee515f876: 0 SCCs
# Collection 0x5f4becdcfcbeaf8274b6905b101aaf44ac10012c: 0 SCCs
# Collection 0x5f5c08f823aeeddc8a4e53e4f144e7a8f50d3b37: 0 SCCs
# Collection 0x5f8061f9d6a2bb4688f46491cca7658e214e2cb6: 0 SCCs
# Collection 0x5fb784ed9d2e5b2eca16cb8f467e03a8b7ea22cd: 0 SCCs
# Collection 0x5fd7001dedc58476dc8be47e9e38e09e9e5d73c4: 0 SCCs
# Collection 0x60909c259cb13021c834c9653c55057ff589fce0: 0 SCCs
# Collection 0x60d92741bf44a4a7c240bbad29e328ff74232268: 0 SCCs
# Collection 0x60e795f7aa87c0def180a9754e60d21325b63ec6: 0 SCCs
# Collection 0x60f3680350f65beb2752788cb48abfce84a4759e: 0 SCCs
# Collection 0x60f80121c31a0d46b5279700f9df786054aa5ee5: 0 SCCs
# Collection 0x61097cc82c503ff2d95ce11edd93e0f0cab30c59: 0 SCCs
# Collection 0x6110604b8bfec3f3e97231cd1ed36b16faefa9f7: 0 SCCs
# Collection 0x612004c1c172e1a773423d085e1324a8f8250a8e: 0 SCCs
# Collection 0x617913dd43dbdf4236b85ec7bdf9adfd7e35b340: 0 SCCs
# Collection 0x618dc60c5cae3b42a3983f4c870bdf57a8037186: 0 SCCs
# Collection 0x61bd6b10c7bf3e548f8659d016079e099510a4dc: 0 SCCs
# Collection 0x623bfb0cd11b9ad3a67b00a7190ce1915c0f3ecc: 0 SCCs
# Collection 0x629a673a8242c2ac4b7b8c5d8735fbeac21a6205: 0 SCCs
# Collection 0x6338191071747abc74d7644d71b49c07289b1eff: 0 SCCs
# Collection 0x6357864c93119eb47a06e0283376d4dd85adf821: 0 SCCs
# Collection 0x638581a33b2e07663894a7f02f2b330dad6efedf: 0 SCCs
# Collection 0x63984ef7a91ea69cdad6c7071890ee4d2fccab4b: 0 SCCs
# Collection 0x63e0eab409f1c1e737aad225003d709b57dbe9e5: 0 SCCs
# Collection 0x644c10cc2b33e201a714a6b69bff1d59d34442f3: 0 SCCs
# Collection 0x64ba65ec863cb7db28c513f53804d9c4d56c14f2: 0 SCCs
# Collection 0x64cbc6b5b5f1f10a213faee828a5f43dc385ad59: 0 SCCs
# Collection 0x65061eafee6e4d49c40497a7dcd86865541f6960: 0 SCCs
# Collection 0x6524b87960c2d573ae514fd4181777e7842435d4: 0 SCCs
# Collection 0x65770b5283117639760bea3f867b69b3697a91dd: 0 SCCs
# Collection 0x658c7df4db0fa54d01ffe584b473958a7e38d7ef: 0 SCCs
# Collection 0x65b9344d3d81f2c00da30e303f8ec40110857495: 0 SCCs
# Collection 0x65f61803907d483c9c504f3b0602c41a664970db: 0 SCCs
# Collection 0x66018a2ac8f28f4d68d1f018680957f2f22528da: 0 SCCs
# Collection 0x6656b20a5d6ccdc95aea98764285cf9d3e6ff3ce: 0 SCCs
# Collection 0x677d8fe828fd7143ff3cee5883b7fc81e7c2de60: 0 SCCs
# Collection 0x67cbbb366a51fff9ad869d027e496ba49f5f6d55: 0 SCCs
# Collection 0x682575b74a00ff87f74fc5f83c34220de50102ba: 0 SCCs
# Collection 0x690c231a00a2bbe474d06d47372f7a2cdf2afa99: 0 SCCs
# Collection 0x692651a8cfcdfc81d0d4f1caf8a6e64bc93d1dbb: 0 SCCs
# Collection 0x6960de09c7d6b1155a0d4482c032c8e3eb8163bc: 0 SCCs
# Collection 0x69ae84b7e80d72d8f6241dd72ae0c331738f334a: 0 SCCs
# Collection 0x69e92c16b66020e6c22bb6e478c6dcebb72f8b70: 0 SCCs
# Collection 0x6a5ff3ceecae9ceb96e6ac6c76b82af8b39f0eb3: 0 SCCs
# Collection 0x6a880ec5edd06a97f7997bdfd605ea4319e80b82: 0 SCCs
# Collection 0x6a99abebb48819d2abe92c5e4dc4f48dc09a3ee8: 0 SCCs
# Collection 0x6ac07b7c4601b5ce11de8dfe6335b871c7c4dd4d: 0 SCCs
# Collection 0x6ade36be35b0fd03e0bc06e469b71a35e25d8a0a: 0 SCCs
# Collection 0x6ae270426644c8846297a0eabe8f448534420906: 0 SCCs
# Collection 0x6ae535c1871f1078a90e8165a83c387f06014333: 0 SCCs
# Collection 0x6b31a2ef5986d283332e4a3a608adb3c09ffdd13: 0 SCCs
# Collection 0x6b387bc3577e53a0bf5e952c1ecbc83a39653026: 0 SCCs
# Collection 0x6b47e7066c7db71aa04a1d5872496fe05c4c331f: 0 SCCs
# Collection 0x6b4fccdd888bb6fd3934a9e49ef64dfd2c0d8e6d: 0 SCCs
# Collection 0x6c10511ddea5f3ed38a0163224198e37b81525bc: 0 SCCs
# Collection 0x6c2a20b920a943237688dd6651200cab253f5565: 0 SCCs
# Collection 0x6c4200d16a7b05e3f7040a69d574835382571f8f: 0 SCCs
# Collection 0x6c7b6cc55d4098400ac787c8793205d3e86c37c9: 0 SCCs
# Collection 0x6cc462bc49cecfe943bc4f477b23b92906e6074f: 0 SCCs
# Collection 0x6cf69ef13d4bf029867e1042f111b8b4adf0dbf4: 0 SCCs
# Collection 0x6d389e3b8e4d2c6cc1daa4c1ec002779d85a6a5c: 0 SCCs
# Collection 0x6d4530149e5b4483d2f7e60449c02570531a0751: 0 SCCs
# Collection 0x6d696d6982d2332f44358d9673c14a33780ea531: 0 SCCs
# Collection 0x6d8cc2d52de2ac0b1c6d8bc964ba66c91bb756e1: 0 SCCs
# Collection 0x6e058ccbb49b05ada07f2cf75f7f4647901b5b3f: 0 SCCs
# Collection 0x6e5322ee2ae9ac0f90e979b8aced243a2ea8722d: 0 SCCs
# Collection 0x6e91869090a430e6ba6ffa7c585742e56fed2247: 0 SCCs
# Collection 0x6f464c779c020a8303a805dcd5e278dfa3913de3: 0 SCCs
# Collection 0x6fa769eed284a94a73c15299e1d3719b29ae2f52: 0 SCCs
# Collection 0x6fc8002029093c77e85252b3100140908d7aac85: 0 SCCs
# Collection 0x6fce4a2d220d5a975eecfec0d2e0a81d3247d342: 0 SCCs
# Collection 0x6ff08fdafc834e9802f6f2fd181ab84ea111f576: 0 SCCs
# Collection 0x70c5ae7fc63a2d4b61ba2fa5c6c700f8ddfe083d: 0 SCCs
# Collection 0x70e120bedba35694fd97045cc39b2c5b15b0fdff: 0 SCCs
# Collection 0x7137c6ded150b38c697955bc26ba6e0a76cb7737: 0 SCCs
# Collection 0x71aaeb055fbd9ad073313408513f875ce7d7451f: 0 SCCs
# Collection 0x71c118b00759b0851785642541ceb0f4ceea0bd5: 0 SCCs
# Collection 0x72262848c8b95532fcfffe6e3e519b228ae5845b: 0 SCCs
# Collection 0x729b3a486407a01b2fdbf4f8f90aa7ff5f20b0f1: 0 SCCs
# Collection 0x729cd6226751279030757f61b2cac4798c949fa1: 0 SCCs
# Collection 0x72ada42494f4080a02847f6630f1d90af4498124: 0 SCCs
# Collection 0x739039c187655590367f96158201c941a61d440a: 0 SCCs
# Collection 0x73c989f89964eccfe26353508dca86bda01e031b: 0 SCCs
# Collection 0x73d203f6138030f17706a99d760e05d01cab83e8: 0 SCCs
# Collection 0x73da73ef3a6982109c4d5bdb0db9dd3e3783f313: 0 SCCs
# Collection 0x73f126ef29bd62038c95179cfcbed2f49f1db8a8: 0 SCCs
# Collection 0x744481b9b295fbef4636eff8ffe7d2901246dcfe: 0 SCCs
# Collection 0x7449afeeb974d1bc43bdac43a21c6c410c0f6277: 0 SCCs
# Collection 0x74c15877d8a4d4e193719e4c36f0076b9d0ce4b5: 0 SCCs
# Collection 0x74f1334e210bbd0ae2555ec212019cd77a6a36ff: 0 SCCs
# Collection 0x753c3a8567311c8673182847f5e390d960a1e4d0: 0 SCCs
# Collection 0x75a3752579dc2d63ca229eebbe3537fbabf85a12: 0 SCCs
# Collection 0x75dbcd6e20f535b3eccdd1c53544c7ea34ce5edc: 0 SCCs
# Collection 0x760478dd60aa995d275a84d05fcab8addc0f2468: 0 SCCs
# Collection 0x76ad70096b373dce5c2bf44eb9a9f8ecbb1c0b93: 0 SCCs
# Collection 0x76bd634d66265f4138f46df36efe89c61ce7396a: 0 SCCs
# Collection 0x76be3b62873462d2142405439777e971754e8e77: 0 SCCs
# Collection 0x76f71dcfd0bd0dbeb0ffc7decd0b327cb7dfdc84: 0 SCCs
# Collection 0x772f52ca0cf135462a334a1e5a990047ad046b6a: 0 SCCs
# Collection 0x77301021b53a871e9f14ad1b6762a619c58014e4: 0 SCCs
# Collection 0x774418646555f414cbaeca6cf3c72a0613d4dab4: 0 SCCs
# Collection 0x778cc248cdddfd926bfba49850098eac16b0d12a: 0 SCCs
# Collection 0x7885584a108e7996f415585a094e6914b169d87c: 0 SCCs
# Collection 0x78d2b35af227099139367ae407b106913738ccfe: 0 SCCs
# Collection 0x78d551cd9e5ad303b6bb60df75e21ad22480de93: 0 SCCs
# Collection 0x7920f98733b912772f89dbdd95e221bb7e6d058f: 0 SCCs
# Collection 0x79986af15539de2db9a5086382daeda917a9cf0c: 0 SCCs
# Collection 0x79f75e9f93f89d33c20573dec03710c6d9ec538d: 0 SCCs
# Collection 0x7a39cc62642826b0ee8622cdf4586f80c684b5e8: 0 SCCs
# Collection 0x7a6e63979d05b22d9da02acc7380f5a92266d953: 0 SCCs
# Collection 0x7a82a20e7669a9313662ba1c9d9cf0502be8ab9d: 0 SCCs
# Collection 0x7a974b387eae135323d91309830f8119be4f9b46: 0 SCCs
# Collection 0x7b4d47feb4d6cef88302d7272da337b050f48a8f: 0 SCCs
# Collection 0x7c10bc61de6781caa00f2f6d8eb4822684337a2b: 0 SCCs
# Collection 0x7c40c393dc0f283f318791d746d894ddd3693572: 0 SCCs
# Collection 0x7c99dedb1dd8b9c9b12a8043c569988c3f881550: 0 SCCs
# Collection 0x7ccdc136619cddf744122a938b4448eda1590fe1: 0 SCCs
# Collection 0x7cda0da532827732cf326b957ef894b3d22d1f6a: 0 SCCs
# Collection 0x7cdc0421469398e0f3aa8890693d86c840ac8931: 0 SCCs
# Collection 0x7d0960fec1353a79c743d271de6c94316e65c374: 0 SCCs
# Collection 0x7d2661b855a4d2ca8cf1dcd63df8e58192e4ea22: 0 SCCs
# Collection 0x7d5df12ffc153c9020efa92b036d56bb53b8323e: 0 SCCs
# Collection 0x7d72da80084359751122a11af5305f38df18e246: 0 SCCs
# Collection 0x7e0748d39553e780257a24f4786c627ad361d003: 0 SCCs
# Collection 0x7e1b993040be1001ab2d6ea736b56ddb070a771d: 0 SCCs
# Collection 0x7e439a012e06b9bd4a9a08a0a945b46bea3a215b: 0 SCCs
# Collection 0x7e61ef40aa09f6fa557519bc93ecddefcd61c753: 0 SCCs
# Collection 0x7e789e2dd1340971de0a9bca35b14ac0939aa330: 0 SCCs
# Collection 0x7f230741e6ef6937ba389134d272f239ea9dc511: 0 SCCs
# Collection 0x7f72528229f85c99d8843c0317ef91f4a2793edf: 0 SCCs
# Collection 0x7fc0552df341fe7052efc8a2806a7c9bddeb23d0: 0 SCCs
# Collection 0x7fdcd2a1e52f10c28cb7732f46393e297ecadda1: 0 SCCs
# Collection 0x7fe96546314f3336fa838020b36ad01ed28be2f2: 0 SCCs
# Collection 0x8041cf97465a919786e4f1dd15c52674daf809bd: 0 SCCs
# Collection 0x806dd42004d3668d528c3de007cc9255a96b8da3: 0 SCCs
# Collection 0x80998e8ff2b2b8f2aa2cac096297c7516726844e: 0 SCCs
# Collection 0x814f3965cddc69cf491369a2391adb9b91863c71: 0 SCCs
# Collection 0x818737eec8a5350756da40d5ddafda8a84ade107: 0 SCCs
# Collection 0x819d965d8e0a1d9852e805dec073084bd3c5637f: 0 SCCs
# Collection 0x81ab26093b7250ffce07cdd40540028c5c968b08: 0 SCCs
# Collection 0x81b0c8cb62daf41f3b6629c38914dbe898a9fbe7: 0 SCCs
# Collection 0x8280d56ac92b5bff058d60c99932fdecdcc9441a: 0 SCCs
# Collection 0x82fdd32e998536609b624e033a16a879d2ebefe5: 0 SCCs
# Collection 0x837779ed98209c38b9bf77804a4f0105b9eb2e02: 0 SCCs
# Collection 0x83b4b74a9fc65bf26aa4f68044b51cff0fc23cc4: 0 SCCs
# Collection 0x8562c38485b1e8ccd82e44f89823da76c98eb0ab: 0 SCCs
# Collection 0x85f0e02cb992aa1f9f47112f815f519ef1a59e2d: 0 SCCs
# Collection 0x862c43f70b74cd5f3b0c431435dbbf5e0608332f: 0 SCCs
# Collection 0x864ff5975607fb053056a4fb4c67f557028f7320: 0 SCCs
# Collection 0x86c4bb362e90bd859ac60dacd7c7a02954ceda63: 0 SCCs
# Collection 0x86f76990b265cd5c9789b556d6fe3f8e7f909674: 0 SCCs
# Collection 0x872a2d8d43f4eaed69188a40b373dde945709ad8: 0 SCCs
# Collection 0x8746166c2381143d3eea3b5970974c38093e2e2c: 0 SCCs
# Collection 0x8754f54074400ce745a7ceddc928fb1b7e985ed6: 0 SCCs
# Collection 0x875955af00d2a67786aed9501f92a2ce98750aa6: 0 SCCs
# Collection 0x876295342f2cda8d83e05f395063efa676535c43: 0 SCCs
# Collection 0x87b3f848f9795c4a6accf69ee962a9857634ae22: 0 SCCs
# Collection 0x87d598064c736dd0c712d329afcfaa0ccc1921a1: 0 SCCs
# Collection 0x87df2103941187dc230eab1a148a587cb8a03afb: 0 SCCs
# Collection 0x88000cd082328e1627f09db72b7762572565afc7: 0 SCCs
# Collection 0x88203cc4ce6f9ee12a7bbfc1c4c7faf0bdc7c984: 0 SCCs
# Collection 0x882ecef51418d6bcf6ff9c3c9991b09ae8d1d6af: 0 SCCs
# Collection 0x8853b05833029e3cf8d3cbb592f9784fa43d2a79: 0 SCCs
# Collection 0x8863fbcb4b86d0b4813ca52a30b3f5f6b81dacf7: 0 SCCs
# Collection 0x892555e75350e11f2058d086c72b9c94c9493d72: 0 SCCs
# Collection 0x89505d2a27b7e8ac56252081d721ecd525e4241e: 0 SCCs
# Collection 0x8995ad7deabd17c31b62ac89ee5f7d850a4bedb0: 0 SCCs
# Collection 0x89b1d42af08bccb0e8168dbf92f800573ae84c73: 0 SCCs
# Collection 0x89cbd0ad7f5c10efa66e5d15a35ba5813ef76140: 0 SCCs
# Collection 0x89ee76cc25fcbf1714ed575faa6a10202b71c26a: 0 SCCs
# Collection 0x8a59b9f658c3dac396a9c380a5a8044b02caf68c: 0 SCCs
# Collection 0x8a939fd297fab7388d6e6c634eee3c863626be57: 0 SCCs
# Collection 0x8a954618dec93ca46405ecb182823242fbb9fc27: 0 SCCs
# Collection 0x8ae06a29a816580cbd069e460dd57c6c964bb3da: 0 SCCs
# Collection 0x8ae8d2ae74a96595bcdab803b563f594009e3db2: 0 SCCs
# Collection 0x8aec2951a4368d5a30a17bf111cfae3f9ee403da: 0 SCCs
# Collection 0x8aff6a8320ba596c59df10a56b2420229294366e: 0 SCCs
# Collection 0x8b8474a376bade9fd22e51bea2e3a94d157af090: 0 SCCs
# Collection 0x8bc67d00253fd60b1afcce88b78820413139f4c6: 0 SCCs
# Collection 0x8bcb9a74144e6498ea90b5c5ebeb78f4a6b12c0f: 0 SCCs
# Collection 0x8bf592fd4217f064327d1db45a58c66f6d297584: 0 SCCs
# Collection 0x8c521b1179b681c7ef048ec43073a26523d06d6a: 0 SCCs
# Collection 0x8c9b261faef3b3c2e64ab5e58e04615f8c788099: 0 SCCs
# Collection 0x8cb813bf27dc744fc5fb6ba7515504de45d39e08: 0 SCCs
# Collection 0x8cf3d6bbaead351bdd4533691855d08b2d814a2d: 0 SCCs
# Collection 0x8d67ecc9cdf0c19e170629a6557d210fbb8e6123: 0 SCCs
# Collection 0x8da0b54dfe61ef2650fdfbde440d0d3983b7a0f9: 0 SCCs
# Collection 0x8da8806fc0c459fce4625789374972693befc03f: 0 SCCs
# Collection 0x8dc3be37a1d83a174a4d417980bcb455e347ba65: 0 SCCs
# Collection 0x8e44ebb62ef1d1191eda8e5f1cb2ffc279182c5b: 0 SCCs
# Collection 0x8e893534f8ba4183d6303fe27ffecac34b7b25a1: 0 SCCs
# Collection 0x8eeb1c420767d7ddd927d05d46c93bf6ba0ef9d0: 0 SCCs
# Collection 0x8f2256063036495f5a362a57757acfcbe72e44b9: 0 SCCs
# Collection 0x8f2366d7379d2783f2e1b35d3f82ac26a717fcbf: 0 SCCs
# Collection 0x8f49d8f7aeb49102710c652af556cf346e3057a2: 0 SCCs
# Collection 0x8f56406622d712778682181c66c2fe70123bcbba: 0 SCCs
# Collection 0x8f9cb66a4fb2dcff44da04dfdd5fac550a3ddfae: 0 SCCs
# Collection 0x90709c29b779e5228e86ff04bb60a3643ea3e0e6: 0 SCCs
# Collection 0x909899c5dbb5002610dd8543b6f638be56e3b17e: 0 SCCs
# Collection 0x90f9a7dffd55fc1bcccadf72adbb0a3f5daea7a6: 0 SCCs
# Collection 0x9103650d8c0fe6600de16d9f17d9b84910d43df5: 0 SCCs
# Collection 0x91047abf3cab8da5a9515c8750ab33b4f1560a7a: 0 SCCs
# Collection 0x9126b817ccca682beaa9f4eae734948ee1166af1: 0 SCCs
# Collection 0x913ae503153d9a335398d0785ba60a2d63ddb4e2: 0 SCCs
# Collection 0x91c3373f6e49bcc9ff313572493c77e8aaa752b8: 0 SCCs
# Collection 0x91cc2cf7b0bd7ad99c0d8fa4cdfc93c15381fb2d: 0 SCCs
# Collection 0x9201a886740d193e315f1f1b2b193321d6701d07: 0 SCCs
# Collection 0x9237cb5a161b860c65c61330e090cdebd847b6cf: 0 SCCs
# Collection 0x9255ed258dcbafe165dccd93ea0a72f4ed88e24d: 0 SCCs
# Collection 0x929167191ca41a4753eda357bb6e5ad6f15fb89b: 0 SCCs
# Collection 0x92a033a582920f2653d608b6c1bc9dfee2f0db0e: 0 SCCs
# Collection 0x92cb5f1fbabbcbdd891b9cbd8e9a056c8c1eebef: 0 SCCs
# Collection 0x92e1121149ac6c71a00555d62e41054910495616: 0 SCCs
# Collection 0x93ea6ec350ace7473f7694d43dec2726a515e31a: 0 SCCs
# Collection 0x9498e391ca49722988fc4da4d0d8c9c987ce8961: 0 SCCs
# Collection 0x94ac35c4225d63f01e1cdd31f6c566f3b9398787: 0 SCCs
# Collection 0x9505a05046c828af5b1f7c565c1f87ee30c25d4e: 0 SCCs
# Collection 0x959e104e1a4db6317fa58f8295f586e1a978c297: 0 SCCs
# Collection 0x95c77f3ffc2a01baf1aee5342f80a5ce98c9f9e4: 0 SCCs
# Collection 0x95f862fba8879a2795a67ae556eefc3bd6302bce: 0 SCCs
# Collection 0x960c6d43199e34dfdd9022e7ebdb9d154acc1c8b: 0 SCCs
# Collection 0x960f401aed58668ef476ef02b2a2d43b83c261d8: 0 SCCs
# Collection 0x962a71bb0d2bb118fbe021e320f58c8f9236a700: 0 SCCs
# Collection 0x9680223f7069203e361f55fefc89b7c1a952cdcc: 0 SCCs
# Collection 0x96bc32f1e544fcbf586f9d2002c6c295b47f1000: 0 SCCs
# Collection 0x96da7bc30381e7d290c1bb491d8e99bd67c5cb40: 0 SCCs
# Collection 0x97104a712941830bd9b78e4a09c1cf384a8c9d6a: 0 SCCs
# Collection 0x97ca7fe0b0288f5eb85f386fed876618fb9b8ab8: 0 SCCs
# Collection 0x97cc6bc80fe6c88f054e04593081e9ff9881e364: 0 SCCs
# Collection 0x9839499c38acbd6e11b4af0e50cc2259bffeac51: 0 SCCs
# Collection 0x985af49e515488c6556e3d9d24d464ce95ea3088: 0 SCCs
# Collection 0x989e1fb123b67afd66e10574c8b409bc6e812d9a: 0 SCCs
# Collection 0x98ff4553a3dcbf5e4ff8b5d4cc6fb763b6f20174: 0 SCCs
# Collection 0x9925b7d92dfe10a4dcef2c873a56c7c3c7c8b656: 0 SCCs
# Collection 0x9951f5da4f4f21b7d39a80bc665edf31bd515009: 0 SCCs
# Collection 0x9a22e489db7c2e48c284e9b2d32d9c4b8f7108f2: 0 SCCs
# Collection 0x9a41cd49126a53b796dbbdcf8ce163e989465111: 0 SCCs
# Collection 0x9abb7bddc43fa67c76a62d8c016513827f59be1b: 0 SCCs
# Collection 0x9b1aa69fe9fca10aa41250bba054aabd92aba5b6: 0 SCCs
# Collection 0x9b26616ee0cbd466e072e86a99b4bfa4a3489bf4: 0 SCCs
# Collection 0x9b3c6e9636e0c220a2ef9517d1e7ad0bb34d7d2f: 0 SCCs
# Collection 0x9b87d15470e3be38aa536212c52132e3c67cc2c8: 0 SCCs
# Collection 0x9be29d790c7e2c3ff6acb608f6a3799b2650314d: 0 SCCs
# Collection 0x9bf3e18ba8104492d3e3c1654daa888aadc7ba45: 0 SCCs
# Collection 0x9c1d606c8b9ed5f3c7cbec84615344b1e4987fcd: 0 SCCs
# Collection 0x9c3aebe3af3abc5b9bac0f7c272f115ef04b41dd: 0 SCCs
# Collection 0x9c965e8e0d2de351295c25f85a8af6e40b19e318: 0 SCCs
# Collection 0x9caeba1049f2f7f56ec561186b3ca6009e4b7b86: 0 SCCs
# Collection 0x9cb034035cb35699633ca162f0ef859ec29d830e: 0 SCCs
# Collection 0x9d060a74befd28c6431f86171cd5982bcce1bbab: 0 SCCs
# Collection 0x9d34c91d03809bc012768d8c608e862c0c985b81: 0 SCCs
# Collection 0x9d664ec54b3d1549045cd57d67998687a0dd371a: 0 SCCs
# Collection 0x9d9c250311b65803c895cc77f878b8092019dedc: 0 SCCs
# Collection 0x9da8081f9968e6de274082849df797e6137f6fc6: 0 SCCs
# Collection 0x9db37d15fefbf42dc390c3c81fee453465841038: 0 SCCs
# Collection 0x9e1f3e8db4d1119894624632499eaed1e56d2b1d: 0 SCCs
# Collection 0x9ec867eeaf55fc8be53dd0ce552262ddbdf70905: 0 SCCs
# Collection 0x9f5b1fa6ec33513b8a9f22cea0acdc9c3b2835b2: 0 SCCs
# Collection 0x9f75a77966ade660782f73f822c836c32be6784a: 0 SCCs
# Collection 0x9f9c171afde4cc6bbf6d38ae4012c83633653b85: 0 SCCs
# Collection 0x9fbe7ace6cb0b05b8cc95686cf7c0bdb0f88e3d6: 0 SCCs
# Collection 0xa0244afbc4d0366eebbd4cbfcf82ce49547d8eaa: 0 SCCs
# Collection 0xa0f724f5d2b021afefb4a4ecb6058164c34355da: 0 SCCs
# Collection 0xa13325ba1b9493c02d364a4a41e646d24f532126: 0 SCCs
# Collection 0xa17da9b6ce8f4e1bc8e26eb7d87976bedbc0c939: 0 SCCs
# Collection 0xa194bef56be26c2ac087de7514e9855c5b944544: 0 SCCs
# Collection 0xa1b618929713134b6dda32a33e2e36d6a0cf52ef: 0 SCCs
# Collection 0xa20f75be9427995e596788c29a10c7d734671251: 0 SCCs
# Collection 0xa27a9b68367b04bf63d1edd27337f0c239cca13a: 0 SCCs
# Collection 0xa2b35bbaa4a3050aad0cb205365ec2d8a24ccc1c: 0 SCCs
# Collection 0xa2d544196fdbc9da15a701c38bb60513c1802ef4: 0 SCCs
# Collection 0xa2f48155742730dd1f6c8b434b2ce44fef170820: 0 SCCs
# Collection 0xa342f5d851e866e18ff98f351f2c6637f4478db5: 0 SCCs
# Collection 0xa3d23c04992d740cdfd6ee8d2076c1a0220b672f: 0 SCCs
# Collection 0xa3f0100e53cfffc34822c8b82ffde1e91c429472: 0 SCCs
# Collection 0xa421ec3870aed95f639fb64dde34bbb0843f883a: 0 SCCs
# Collection 0xa4272fd56b5ca4a66a7cff8cbe7e0e7c590705d1: 0 SCCs
# Collection 0xa467a1b040dba0f3e42c3f5208f8a3f826890047: 0 SCCs
# Collection 0xa5469b5ffd65069191425d1f7db865fdc10421c5: 0 SCCs
# Collection 0xa571995a60c04471baff944ab4c360c7ed1019c1: 0 SCCs
# Collection 0xa58b5224e2fd94020cb2837231b2b0e4247301a6: 0 SCCs
# Collection 0xa5e5be69c923c701ae6ac8f1f5936af3ae610c68: 0 SCCs
# Collection 0xa5efd7a7b3bb0de53bc3f2aa59004722d1431a15: 0 SCCs
# Collection 0xa5fe4205c2aaed761eb89faa5b87e13954e3cb73: 0 SCCs
# Collection 0xa61ae7614636740e5a0cbce70141aa6c8589a7db: 0 SCCs
# Collection 0xa63b627199214d71234e075e4557083fe033059f: 0 SCCs
# Collection 0xa6d954d08877f8ce1224f6bfb83484c7d3abf8e9: 0 SCCs
# Collection 0xa75a3f5b447d3d929e5b2ca157cfe7046bc15b37: 0 SCCs
# Collection 0xa7823d6fdb8c3d522fc5720e4a4f5f1f0352567c: 0 SCCs
# Collection 0xa7a3baa3553ef91377cbef42642809e0caeb52f2: 0 SCCs
# Collection 0xa7d8d9ef8d8ce8992df33d8b8cf4aebabd5bd270: 0 SCCs
# Collection 0xa7e7fb2e17868bc4e336dc6834168c31fb59fc67: 0 SCCs
# Collection 0xa7eb9a6a3a86b2fda7199a2e151aaef84cd1dfda: 0 SCCs
# Collection 0xa7f87e8d193e29bf1ed050fdd511b79fe0264d8b: 0 SCCs
# Collection 0xa8005a8ca1a4e8ed2283386d812d38e038969a6c: 0 SCCs
# Collection 0xa81e0193f30bbd6e83366a88b4570e8766ca2131: 0 SCCs
# Collection 0xa862659b349bcea17ffc62a2f3e85909318c4b62: 0 SCCs
# Collection 0xa864865b83b0b7c95c3c108f5a3896308979bdbd: 0 SCCs
# Collection 0xa889b86239ef747ca9f63e1854b7050bea244db0: 0 SCCs
# Collection 0xa8abf045fe1a9ef0583e436393a6e4e0b483f717: 0 SCCs
# Collection 0xa8ee490e4c4da48cc1653502c1a77479d4d818de: 0 SCCs
# Collection 0xa8f9a747653ce85cc7277a09a986f7b0eacc8b69: 0 SCCs
# Collection 0xa9133ae151a87c1044287e0d19aa7baa195d4399: 0 SCCs
# Collection 0xa9354f07c3e9bc1e3effbdf790a0b6dc05a46af8: 0 SCCs
# Collection 0xa9823611aa152b6efe4eca3e51ac74998b5d7afe: 0 SCCs
# Collection 0xa983b3d938eedf79783ce88ed227a47b6861a3e9: 0 SCCs
# Collection 0xa98771a46dcb34b34cdad5355718f8a97c8e603e: 0 SCCs
# Collection 0xa9cfc59a96eaf67f8e1b8bc494d3863863c1f8ed: 0 SCCs
# Collection 0xaa0d5b39a4664d8d700b7e12c164ed43b951554f: 0 SCCs
# Collection 0xaa8e5c0ca8de723a00fced8ac6f9720e71dffd71: 0 SCCs
# Collection 0xaaa995adca2bfc50130c211dd26989728d90f258: 0 SCCs
# Collection 0xaac1c334fa3e791904439c5f217f53dccbf7ea59: 0 SCCs
# Collection 0xaafba0555828c98216a7254b8500043ab27ce4f0: 0 SCCs
# Collection 0xab089ddf4ceb6a27a5348dcc432933228b725ac0: 0 SCCs
# Collection 0xab7ff2afd4176f5d82d071e83c814a0dd7fb1195: 0 SCCs
# Collection 0xab843fb5c8aacd611c9b894908977fe949440857: 0 SCCs
# Collection 0xabc7e6c01237e8eef355bba2bf925a730b714d5f: 0 SCCs
# Collection 0xabec196c7c3e074b5552e04364e304e39a2723c2: 0 SCCs
# Collection 0xabefbc9fd2f806065b4f3c237d4b59d9a97bcac7: 0 SCCs
# Collection 0xac11d6f8f840a97aeba2e658aaf02ce0afbcc34c: 0 SCCs
# Collection 0xac1aee5027fcc98d40a26588ac0841a44f53a8fe: 0 SCCs
# Collection 0xacd42c32ca13b1d5d3292a97363498b20e8768b8: 0 SCCs
# Collection 0xad14707be6ce1896188abecd74a8889d97c4c181: 0 SCCs
# Collection 0xad3018b6c203174f9a84373fcf862300147ba5f6: 0 SCCs
# Collection 0xadcc60f4736fdb3c1a3e4966cf172af62ed6d036: 0 SCCs
# Collection 0xaddbf4405a5711201e3ff3074ab272697d4e4a97: 0 SCCs
# Collection 0xae03fae2a53b5ab3797faf3e8d6af8cde4594e2a: 0 SCCs
# Collection 0xae28f53deb0d0dbb224bedfe3b70f1095781befb: 0 SCCs
# Collection 0xae3d268396fc48483edb1e7a25bc95b6790c0320: 0 SCCs
# Collection 0xae6e071de3b277952b56cb7fc1b5c7cb02d5b4a9: 0 SCCs
# Collection 0xaea81ee023df032139188f3d15be281037e5b377: 0 SCCs
# Collection 0xaef8bec601fc9f1dc2f9bf0c4d04df4095ce5b7f: 0 SCCs
# Collection 0xaefc66bf4c64b5df1e12a8fbd3f7f86ee9bb590d: 0 SCCs
# Collection 0xaf488234796ca27dba8ecf17f803ea1f4ab33e15: 0 SCCs
# Collection 0xafb44cef938b1be600a4331bf9904f6cec2fcac3: 0 SCCs
# Collection 0xb09a9d46753247944193149103a8e3213cbd717b: 0 SCCs
# Collection 0xb0d09c8aa8a9c7c04f03d4139714b9354b8987e0: 0 SCCs
# Collection 0xb0e409b7b0313402a10caa00f53bcb6858552fda: 0 SCCs
# Collection 0xb1432546890d88a0c510ca73475e0c3b8933bf22: 0 SCCs
# Collection 0xb153e6fd8d4da8782d11df9d6bbf63e08ac2258f: 0 SCCs
# Collection 0xb1a34e32371d0c4c1b08f168c113a844944fcad4: 0 SCCs
# Collection 0xb1a4eecf844421e112634bf8231b69531a0698d9: 0 SCCs
# Collection 0xb28eb20f70503f4cf5b826bd22178d376b82b358: 0 SCCs
# Collection 0xb32979486938aa9694bfc898f35dbed459f44424: 0 SCCs
# Collection 0xb396b8699f728735f28a31279d07b1d0d2411baa: 0 SCCs
# Collection 0xb3cdd92323fbbd4f089e9fc73de11bf2bda56061: 0 SCCs
# Collection 0xb3faf6e8af293bd2f87662e785b06ccd35af03bc: 0 SCCs
# Collection 0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb: 0 SCCs
# Collection 0xb50235cd3161f9237facef4e96e9926e813fdcd5: 0 SCCs
# Collection 0xb55c5cac5014c662fdbf21a2c59cd45403c482fd: 0 SCCs
# Collection 0xb574528bab3c61c13c2c180bf45f0ec59cdb8eab: 0 SCCs
# Collection 0xb5c461ae792ae429fa175450e1d2af7f494ea20f: 0 SCCs
# Collection 0xb610f0e48fbec040fc803fb3a4fb66fa39c525c9: 0 SCCs
# Collection 0xb69c1820b0c1dced68ecd2d89aae3226bbab8e65: 0 SCCs
# Collection 0xb6dae651468e9593e4581705a09c10a76ac1e0c8: 0 SCCs
# Collection 0xb722cd2bfaa4f62fd43854b1db3342ad120c184c: 0 SCCs
# Collection 0xb75a7e9115d10aaa6512245f7b3e7c52bced6830: 0 SCCs
# Collection 0xb78a1be5e318fc040f76237c3f16961a28081fb6: 0 SCCs
# Collection 0xb791e3190b6b0476fce119762b87fe2a2ca36f93: 0 SCCs
# Collection 0xb7f7f6c52f2e2fdb1963eab30438024864c313f6: 0 SCCs
# Collection 0xb80199a27dba0f91b422f0a5afaf02eacc004e51: 0 SCCs
# Collection 0xb80fbf6cdb49c33dc6ae4ca11af8ac47b0b4c0f3: 0 SCCs
# Collection 0xb845da8301c59f742f82bb8a5e00f5160823bd79: 0 SCCs
# Collection 0xb85070695a7599e3f6a8d46e8bd716d1923769b8: 0 SCCs
# Collection 0xb88c3fdc48d3b148aba66a732a83ef8aa71ae861: 0 SCCs
# Collection 0xb91c1aa27a2eb25228b5d1019ec6b24fe73c5535: 0 SCCs
# Collection 0xb9250c9581e4594b7c6914897823ad18d6b78e96: 0 SCCs
# Collection 0xb932a70a57673d89f4acffbe830e8ed7f75fb9e0: 0 SCCs
# Collection 0xb96697fa4a3361ba35b774a42c58daccaad1b8e1: 0 SCCs
# Collection 0xb985b80ebb5af0cd4f5b31e3018302ac15b697e4: 0 SCCs
# Collection 0xb9a0d7992c2cc6e3a209096432ab607bbca5f6c2: 0 SCCs
# Collection 0xb9abb6e7fdc06fe25ac96d3da1c3ef4651ec660a: 0 SCCs
# Collection 0xb9b25168c28499b248bbbe514e685eca1892547d: 0 SCCs
# Collection 0xba503dd9e11eabd91beb4ed87a7e57198eaa9d6b: 0 SCCs
# Collection 0xba5192b7d4c3135d371d2ab7222a7cf360783ee0: 0 SCCs
# Collection 0xba7f66ee97f052a5efae51ba5e7689203db3dae4: 0 SCCs
# Collection 0xba8cdaa1c4c294ad634ab3c6ee0fa82d0a019727: 0 SCCs
# Collection 0xba93d60303a1c049ea7ce0b87a3a274ced5e2f09: 0 SCCs
# Collection 0xbace7e22f06554339911a03b8e0ae28203da9598: 0 SCCs
# Collection 0xbb5ed1edeb5149af3ab43ea9c7a6963b3c1374f7: 0 SCCs
# Collection 0xbc0e164ee423b7800e355b012c06446e28b1a29d: 0 SCCs
# Collection 0xbc17cd7f1a58bda5d6181618090813b3050416b5: 0 SCCs
# Collection 0xbc5370374fe08d699cf7fcd2e625a93bf393ccc4: 0 SCCs
# Collection 0xbcd4f1ecff4318e7a0c791c7728f3830db506c71: 0 SCCs
# Collection 0xbd94f6c90c667dfd46f85ddb4de41fd0bfe4e8d8: 0 SCCs
# Collection 0xbdf2ef43438e5c1150403248f0074481cef44705: 0 SCCs
# Collection 0xbe05d95647ac4b51bca501b7e97d81d5ba470cce: 0 SCCs
# Collection 0xbebe5c5f7a66d7f9106fcef2ebf65c21ec3d6e99: 0 SCCs
# Collection 0xbf282db3d364ecc05c9602a0f3d4d79902b140c1: 0 SCCs
# Collection 0xbf53c33235cbfc22cef5a61a83484b86342679c5: 0 SCCs
# Collection 0xbfde6246df72d3ca86419628cac46a9d2b60393c: 0 SCCs
# Collection 0xc02697c417ddacfbe5edbf23edad956bc883f4fb: 0 SCCs
# Collection 0xc03844f07f86ad1d90a1c4a2a8204dcf00f3a991: 0 SCCs
# Collection 0xc04528c14c8ffd84c7c1fb6719b4a89853035cdd: 0 SCCs
# Collection 0xc0983df152a9ed7a99be899075ca9bafe5d4b15e: 0 SCCs
# Collection 0xc0cf5b82ae2352303b2ea02c3be88e23f2594171: 0 SCCs
# Collection 0xc0d60341cb0ba6ac6ddcd2858e9f3d5c8fe6c45e: 0 SCCs
# Collection 0xc11135fbdd294b88ba50bd7c34d072cbba0b95f3: 0 SCCs
# Collection 0xc12ec45cf9de5c58fe40e09f4f2db8df6120945b: 0 SCCs
# Collection 0xc15fe6595497cfa3f461351469a6030978a7c226: 0 SCCs
# Collection 0xc170384371494b2a8f6ba20f4d085c4dde763d96: 0 SCCs
# Collection 0xc1a8b3d9dd6d2ef23ac55995ded68381d8ec3118: 0 SCCs
# Collection 0xc1caf0c19a8ac28c41fe59ba6c754e4b9bd54de9: 0 SCCs
# Collection 0xc1def47cf1e15ee8c2a92f4e0e968372880d18d1: 0 SCCs
# Collection 0xc1f4b0eea2bd6690930e6c66efd3e197d620b9c2: 0 SCCs
# Collection 0xc233baa25ae0cadb5928550ba437acb2af637f77: 0 SCCs
# Collection 0xc2610cfa7e117390fe0daec4096f0e8af000db5c: 0 SCCs
# Collection 0xc28155dcc7075c183b641bf805a790ac0325af46: 0 SCCs
# Collection 0xc2c747e0f7004f9e8817db2ca4997657a7746928: 0 SCCs
# Collection 0xc2cf795ffb22e8cdb3f96143422247769ab6920a: 0 SCCs
# Collection 0xc2d5bc0fd802bf72f2722617d27558f39fe5804b: 0 SCCs
# Collection 0xc2d8db56c50f253d1279da6760345fe78f784ed9: 0 SCCs
# Collection 0xc328520a8b1cead2489d59c16b7752cb60ebb53d: 0 SCCs
# Collection 0xc35a0aef49069abffbad543cb81fda3412f80034: 0 SCCs
# Collection 0xc36cf0cfcb5d905b8b513860db0cfe63f6cf9f5c: 0 SCCs
# Collection 0xc38c8f281f1e1e217d279a6d58a43d079e28a213: 0 SCCs
# Collection 0xc3af02c0fd486c8e9da5788b915d6fff3f049866: 0 SCCs
# Collection 0xc4e0bf581d0bd8efa48ea2ffa59057f5e2347a8c: 0 SCCs
# Collection 0xc54648d5fc76b1ecbb4f76a33dec7b37caf14f7d: 0 SCCs
# Collection 0xc563b7d10c04c1e1ffccbfa31cb3d67b9698aa8a: 0 SCCs
# Collection 0xc57a4d6895037f0852fb448d7ae1ea52b5b8d82f: 0 SCCs
# Collection 0xc606a4bec95638088496e28f647825c9db145fc4: 0 SCCs
# Collection 0xc633787348f652611c3166209d1fc4cd82b30ada: 0 SCCs
# Collection 0xc63686a17865d4eb022e485014992eb2d8a88b63: 0 SCCs
# Collection 0xc639246eb3758349846e1fbbd2eeb77fbcc13c77: 0 SCCs
# Collection 0xc63b052f6c7675fa987fe71cca11e94aa67b2c8d: 0 SCCs
# Collection 0xc650c00c37d0b62e3bb03ee6c82d4335bb7953d0: 0 SCCs
# Collection 0xc6a02724a3bfbdee37017f9d70c6d3ba5823c7af: 0 SCCs
# Collection 0xc6a422a9b44080a550c11c7c21024a13d302705f: 0 SCCs
# Collection 0xc6b0b290176aaab958441dcb0c64ad057cbc39a0: 0 SCCs
# Collection 0xc6ed99ae56bbcd859a7ecd8a195ea59c00e0b71a: 0 SCCs
# Collection 0xc707d91f2205a507e36ea9dce1ed8a7bd2dc6ab2: 0 SCCs
# Collection 0xc70be5b7c19529ef642d16c10dfe91c58b5c3bf0: 0 SCCs
# Collection 0xc7e5e9434f4a71e6db978bd65b4d61d3593e5f27: 0 SCCs
# Collection 0xc805658931f959abc01133aa13ff173769133512: 0 SCCs
# Collection 0xc9152cde98420fbe297c3952adc01b90e31ee0aa: 0 SCCs
# Collection 0xc92ca2b5b8a996ad2a6fdd97c6d7ed038e61c725: 0 SCCs
# Collection 0xc9d673008b8f08103e7a3e096b6fdd56fc575d49: 0 SCCs
# Collection 0xca008c0bf62c0421b958de86b3d45c86ecae43f1: 0 SCCs
# Collection 0xcaaf7428dcecb3dc4f9736db65d5b3d0b8de6bee: 0 SCCs
# Collection 0xcae3c92a6d4b6520e00eedeada982261332d9494: 0 SCCs
# Collection 0xcb4bf0a3a12e382ee2b9c28587bf18a22a25a143: 0 SCCs
# Collection 0xcb6768a968440187157cfe13b67cac82ef6cc5a4: 0 SCCs
# Collection 0xcb7423812ee240151522c0197cdd5ba580ed82ac: 0 SCCs
# Collection 0xcbbb170c74fed5fe27245a01c61cd219a90bad18: 0 SCCs
# Collection 0xcbf43ef91f5eb6ef28e54978baad078ae03417c1: 0 SCCs
# Collection 0xcc05b7293f494fe696eff36f93e2957ba445ea06: 0 SCCs
# Collection 0xcc42f00298936d58c4dea5ba1c63cb8b9f486cba: 0 SCCs
# Collection 0xcc586618e43dfaaaa07cfebb3288ad43dfbecd26: 0 SCCs
# Collection 0xcc9a66acf8574141b0e025202dd57649765a4be7: 0 SCCs
# Collection 0xcc9f683c2fdbed1801bc8d68a663577d4f3259cd: 0 SCCs
# Collection 0xcca90ddc76c9e3db6fd436eca1d425128b9483ab: 0 SCCs
# Collection 0xccd4b56d975620a7bef48fb5b8b00e28be668780: 0 SCCs
# Collection 0xcd136e30b316837c190241e838639c619516fdf9: 0 SCCs
# Collection 0xcd65bacacea37e65eac019f37f5cb38ae62a7fbf: 0 SCCs
# Collection 0xcdcfb1876467b08d37e6a49582017126df966c5f: 0 SCCs
# Collection 0xcddcc63883683a3e6d5537d0b47074c3accc790e: 0 SCCs
# Collection 0xcde30e7a7f37022a705cd1415046d322e1428578: 0 SCCs
# Collection 0xce53b468d40a5208e7fcc8a4b589ebe0309ba030: 0 SCCs
# Collection 0xce5b23f11c486be7f8be4fac3b4ee6372d7ee91e: 0 SCCs
# Collection 0xce952f518aed9670fb04b8b8ece2654a94188ecd: 0 SCCs
# Collection 0xcea11e8706b67f710c83d79ec7105031decc8068: 0 SCCs
# Collection 0xcebf2f59cde3b7a7eaf03e6a7ad2dc8a7d6b82a5: 0 SCCs
# Collection 0xcef7f7ccbfb1aec8473433a0ada0b06eee91f12e: 0 SCCs
# Collection 0xcf88cff8f98994343f37bc4ec60448c20f0c917e: 0 SCCs
# Collection 0xcf8d9ff26c13ede55cfd21638fcd03ba1b77c6d9: 0 SCCs
# Collection 0xcfbc9103362aec4ce3089f155c2da2eea1cb7602: 0 SCCs
# Collection 0xd06f51965a7ff3d33f47e216b617b2eaab02215e: 0 SCCs
# Collection 0xd07dc4262bcdbf85190c01c996b4c06a461d2430: 0 SCCs
# Collection 0xd08f2d720e0d00ff92c7f9ab2073cee4c208cee2: 0 SCCs
# Collection 0xd0a2b8c5b60bdb9c67c656c422b9a945210479e0: 0 SCCs
# Collection 0xd0bd0d368436b4252116fb1fb6e148c4acf3e72b: 0 SCCs
# Collection 0xd0c402bcbcb5e70157635c41b2810b42fe592bb0: 0 SCCs
# Collection 0xd0e7bc3f1efc5f098534bce73589835b8273b9a0: 0 SCCs
# Collection 0xd14ce4a3251c648e948337e908030d5a835a7c85: 0 SCCs
# Collection 0xd18d8bd9ab44bfc245f1a7cf93f60cf5b4541cde: 0 SCCs
# Collection 0xd1e5b0ff1287aa9f9a268759062e4ab08b9dacbe: 0 SCCs
# Collection 0xd2186d8c1ee0450eee790f96e355b1c497f11d03: 0 SCCs
# Collection 0xd23043ce917ac39309f49dba82f264994d3ade76: 0 SCCs
# Collection 0xd2b27bdecdae910db1983d1d67b5f7404339284f: 0 SCCs
# Collection 0xd2d2a84f0eb587f70e181a0c4b252c2c053f80cb: 0 SCCs
# Collection 0xd2eca00493ea1218a7ad20009ac0a4602839ca2b: 0 SCCs
# Collection 0xd31eb2fe0f30b9bf09d635cc70f3727d7c16cad3: 0 SCCs
# Collection 0xd35147be6401dcb20811f2104c33de8e97ed6818: 0 SCCs
# Collection 0xd3d427d5c2cf01f8dc1777b27719b1d4ce369484: 0 SCCs
# Collection 0xd46cd035e8a68743aeb09572dc1446d46db6bcdd: 0 SCCs
# Collection 0xd498fc4289ecbcf5c9ef033de3ceddc1fc3f6cc3: 0 SCCs
# Collection 0xd4cc46b27eed4eddbad2da3671bb52506414707b: 0 SCCs
# Collection 0xd4e4078ca3495de5b1d4db434bebc5a986197782: 0 SCCs
# Collection 0xd508731686f2c933b849762f9a92539c666584dc: 0 SCCs
# Collection 0xd50a41aaa4add330fc92959f0dcc9ec61e2bfb43: 0 SCCs
# Collection 0xd5d8503ccf8b95ed877258eaa91d12297ead501e: 0 SCCs
# Collection 0xd6076efe1e577deec21afab6ed383b47e9d8dec6: 0 SCCs
# Collection 0xd650282641b033555f9fadc3947914f25635889a: 0 SCCs
# Collection 0xd652d2633cdbfd5f27f50cddb098e708fa8433f3: 0 SCCs
# Collection 0xd6e367f5d0cbf8762feaea4565c60f74f8bd6827: 0 SCCs
# Collection 0xd6e68a5e3f7db9980ba26e0ed8d32e231f510752: 0 SCCs
# Collection 0xd7033cc4fd21b49fa2227d50c21638b6a708c994: 0 SCCs
# Collection 0xd70f41dd5875eee7fa9dd8048567bc932124a8d2: 0 SCCs
# Collection 0xd73aaa94523ae09547a5348486ba3209df666b68: 0 SCCs
# Collection 0xd73be539d6b2076bab83ca6ba62dfe189abc6bbe: 0 SCCs
# Collection 0xd754937672300ae6708a51229112de4017810934: 0 SCCs
# Collection 0xd84b83efb93e6da9ae5b1588ad3e6fd982d164b6: 0 SCCs
# Collection 0xd862d9e36a8d9887ba330fbd1e3edfe76fe6cb1b: 0 SCCs
# Collection 0xd88e12893abd65aba3eb2b6789f4da6a4247ecea: 0 SCCs
# Collection 0xd8cd8cb7f468ef175bc01c48497d3f7fa27b4653: 0 SCCs
# Collection 0xd92e44ac213b9ebda0178e1523cc0ce177b7fa96: 0 SCCs
# Collection 0xd949a444f29ede73f517942eb4d8e3ccdab25d58: 0 SCCs
# Collection 0xd98db983fa7cbd21fd24ac84c9aca430191309c2: 0 SCCs
# Collection 0xd997fe65d5f4259840a220e39b1e9a33b645459b: 0 SCCs
# Collection 0xd99bc798c0d3161c7e2eee3760e8fc14686c9abb: 0 SCCs
# Collection 0xd9c570f5e932e088c9a3b44a697b969efcf03658: 0 SCCs
# Collection 0xda7e17690deb4f2bc18b6ca2b48ddcc0486ead01: 0 SCCs
# Collection 0xdaae81c0077e8917a2eb63bb66ef701ff4781bb0: 0 SCCs
# Collection 0xdb0b761fe78d807dd641ab795ac42ebd5349de9e: 0 SCCs
# Collection 0xdb18eacce41db61e7588b408df8cd90896993f3e: 0 SCCs
# Collection 0xdb4a62d58220db3c23d63c7887fb7b9208018425: 0 SCCs
# Collection 0xdb68df0e86bc7c6176e6a2255a5365f51113bce8: 0 SCCs
# Collection 0xdbb163b22e839a26d2a5011841cb4430019020f9: 0 SCCs
# Collection 0xdceaf1652a131f32a821468dc03a92df0edd86ea: 0 SCCs
# Collection 0xdd4f84e4f3cd31d6c91d80122b5a26cb4ae66bd5: 0 SCCs
# Collection 0xdd7c1be33faa2154a92c5f428df12109c14e1df8: 0 SCCs
# Collection 0xdd8a96c20acd430522564c81f7ae5bb234ac28d0: 0 SCCs
# Collection 0xdd9c7bc159dacb19c9f6b9d7e23948c87aa2397f: 0 SCCs
# Collection 0xddaf2a168833de8c47c58c7f4e0f412146c1d0f9: 0 SCCs
# Collection 0xddc711f9e9152a1d8d4a38ee2903ac8ce912ca3f: 0 SCCs
# Collection 0xdde2d979e8d39bb8416eafcfc1758f3cab2c9c72: 0 SCCs
# Collection 0xddf15e4160148635b48214ee451ba588a709040e: 0 SCCs
# Collection 0xde2377d0a480b17266ce083a1f1824325c8dba6d: 0 SCCs
# Collection 0xde44a816b050fa0b880028c4644f339bdeb8542a: 0 SCCs
# Collection 0xde6123d1e7b0483b16e745ac329750b170ef79d8: 0 SCCs
# Collection 0xdeccd8da4a6f9b6f4a8da8012c11d2da912edb7b: 0 SCCs
# Collection 0xdefca3d2c714f581b94b5a17bb55db7365c109ff: 0 SCCs
# Collection 0xdf003a97fa6b3a14bd8c2ed4c331a9187e127ad2: 0 SCCs
# Collection 0xdf3e1410841124603c89e2a7823bb6a34dda4ee0: 0 SCCs
# Collection 0xdf3eafb7cd32d150ed15a447876b9e1ec9217683: 0 SCCs
# Collection 0xdf5d68d54433661b1e5e90a547237ffb0adf6ec2: 0 SCCs
# Collection 0xdf65d02348ba94d58cd9a46112d8bd4b42cbc351: 0 SCCs
# Collection 0xdf801468a808a32656d2ed2d2d80b72a129739f4: 0 SCCs
# Collection 0xdfb258c93af3f005dca930b3f10afaf2917946df: 0 SCCs
# Collection 0xe03e4721c75188de6dd9ccf4fc0eb7c81399e305: 0 SCCs
# Collection 0xe0450b58eaba0698b0aa6f2784487f78a0565d6a: 0 SCCs
# Collection 0xe04cc101c671516ac790a6a6dc58f332b86978bb: 0 SCCs
# Collection 0xe05add4628fe5f8c4e16c8de06e429de896c0aa2: 0 SCCs
# Collection 0xe114bce907a86d81f321c6fd8d8c51d542022c92: 0 SCCs
# Collection 0xe15e9c0bf6b6b29d3b9e1c921ab2cb09c2194463: 0 SCCs
# Collection 0xe18a32192ed95b0fe9d70d19e5025f103475d7ba: 0 SCCs
# Collection 0xe1bd4b40079cd73d5d55426274a94ee662c0c67b: 0 SCCs
# Collection 0xe1bdb2e8d6b5ff2c05a6d3e9a231599c3e6efc6c: 0 SCCs
# Collection 0xe1fc74a4f7a303b6a7d16c73171734d11a271c1d: 0 SCCs
# Collection 0xe23b9f368d3cfa255f7968dd0491b0d4fea135f5: 0 SCCs
# Collection 0xe28d2d4f778a2061ac2ae1080c76c4bd0a6f2d3a: 0 SCCs
# Collection 0xe2f5349616fda0c35f6c66a14b6256e30dac066e: 0 SCCs
# Collection 0xe34bb610505541b3fceff472dc5449053b632944: 0 SCCs
# Collection 0xe3782b8688ad2b0d5ba42842d400f7adf310f88d: 0 SCCs
# Collection 0xe3870569f9e1836960bf30b5a45fc743cef0ab0e: 0 SCCs
# Collection 0xe39a238d74bdd95a895026fc25ec97fb8a4b1959: 0 SCCs
# Collection 0xe3ea3eafe3fc255f3ebc5b6a2b3345e59e3f2c78: 0 SCCs
# Collection 0xe4597f9182ba947f7f3bf8cbc6562285751d5aee: 0 SCCs
# Collection 0xe4605d46fd0b3f8329d936a8b258d69276cba264: 0 SCCs
# Collection 0xe498ec1aff3c1460f6a818826443fd2a7817e775: 0 SCCs
# Collection 0xe4deeb64e8701116b1d2bdb82dad4c6de2a28845: 0 SCCs
# Collection 0xe4f5e0d5c033f517a943602df942e794a06bc123: 0 SCCs
# Collection 0xe529178bf1ad4f8e01f09037a3c6e96131cff5f3: 0 SCCs
# Collection 0xe54891774eed9277236bac10d82788aee0aed313: 0 SCCs
# Collection 0xe550b04bdf2fac06e4124d731ebe645645b03e06: 0 SCCs
# Collection 0xe55c8732de80cb474c756440082270e3b2ac7af7: 0 SCCs
# Collection 0xe570131be8d38f5efe74232a4b2fa5e56a00c16f: 0 SCCs
# Collection 0xe57b446d45432a1827210240ef18a21059bfe945: 0 SCCs
# Collection 0xe5b60c2fed339385af83cd4fa4a6ea59ac2b90c6: 0 SCCs
# Collection 0xe61aad1c654d8944e4057ee9a1da2773ea25fb67: 0 SCCs
# Collection 0xe65c9866c456c94b49c58286f1686d7e554d1899: 0 SCCs
# Collection 0xe6dc6f2577bc0cb55c0dca518bd8121b206d557d: 0 SCCs
# Collection 0xe714485b00e1062c1dfef1aee64ad6c8b85987f3: 0 SCCs
# Collection 0xe73c9d94a542b1708450e13d12d4b38204dfd72c: 0 SCCs
# Collection 0xe74aedf09367d3272f0fd726f2f9ef693488eefe: 0 SCCs
# Collection 0xe7f8c066ea90be005032262fa13b9c6aa5182bce: 0 SCCs
# Collection 0xe817c927f34b3c8db9322fe03599bf2707a4491a: 0 SCCs
# Collection 0xe8aa46d8d5565cb7f2f3d9686b0c77f3a6813504: 0 SCCs
# Collection 0xe8b2cd982a5255b2edd3ef7f53b26baa1e595dc9: 0 SCCs
# Collection 0xe955f66d88756ab7c604fa5718c24337d6c4b864: 0 SCCs
# Collection 0xe9be55ffedb6c2a2f3f8eac31c60d7f122f79958: 0 SCCs
# Collection 0xe9e3f9cfc1a64dfca53614a0182cfad56c10624f: 0 SCCs
# Collection 0xe9e73d9a49a96ea5197d143f2636980212b074db: 0 SCCs
# Collection 0xe9ef3d6ea53570b5cf730b4c353e8b7ba4ebda73: 0 SCCs
# Collection 0xeaa4c58427c184413b04db47889b28b5c98ebb7b: 0 SCCs
# Collection 0xeb6f174970ccdd51ed72c9978a50d83123322ff3: 0 SCCs
# Collection 0xebb1da4a068fcb9e8b83928a8c3e83ef564f9989: 0 SCCs
# Collection 0xec09758bd8a9313b58d8759533e2687abe34b6dd: 0 SCCs
# Collection 0xec84c1002279ceb21542ac1f604fe56c29912309: 0 SCCs
# Collection 0xeca5209b63bb16447b9deb7559c56b88251e90ce: 0 SCCs
# Collection 0xecf073f91101ce5628669c487aee8f5822a101b1: 0 SCCs
# Collection 0xecf7ef42b57ee37a959bf507183c5dd6bf182081: 0 SCCs
# Collection 0xed098dea07ee0060a80eba5e0b29083b1868119b: 0 SCCs
# Collection 0xed9342fa758e44cf4c96ebec0a45013bfc6c979b: 0 SCCs
# Collection 0xedafd7bd75416584fb9275acff63cb41f89bf38c: 0 SCCs
# Collection 0xedb88cb36ba634b01819b5e2b546834416e4a945: 0 SCCs
# Collection 0xedbca34b7b113fd3694a2450b5787771add5a7d4: 0 SCCs
# Collection 0xedf4b6d672b24925210f1b5b2da04df60b9f64ec: 0 SCCs
# Collection 0xee403b980f45d70f95273ca77be4a887b7209706: 0 SCCs
# Collection 0xee4ba9ffcf1ab4b15bfdd094515914d8710f4881: 0 SCCs
# Collection 0xee4c2297e25739352bdbf4dc6c9b32d27363582a: 0 SCCs
# Collection 0xee5d869ace05628442463041424e4fc176117255: 0 SCCs
# Collection 0xee85966b4974d3c6f71a2779cc3b6f53afbc2b68: 0 SCCs
# Collection 0xeea903d254da4dcfa941df2731975ccc6e770bd9: 0 SCCs
# Collection 0xef36ff3b28f528a37eb2aad4c9316bde4759f9b4: 0 SCCs
# Collection 0xef42c7c855fc915dd1c81cc08101018dd77229e6: 0 SCCs
# Collection 0xef547d017f64863a1a741864d900956081744238: 0 SCCs
# Collection 0xefabe332d31c3982b76f8630a306c960169bd5b3: 0 SCCs
# Collection 0xefdb2becf9c12952b73e9f3e3ebc5c37dec6df79: 0 SCCs
# Collection 0xf016567ffaeb77f32b224467f670adb2543e5b91: 0 SCCs
# Collection 0xf0456f967432aceb0f39899bee2c30ee3c6c8b46: 0 SCCs
# Collection 0xf06059f01f6f08a603c939359a0a1186f7687685: 0 SCCs
# Collection 0xf095c2e133c15c69f147e6f9688465b27ca3063d: 0 SCCs
# Collection 0xf0b6724d259321112be27e1f1c8bdb126d6a8db7: 0 SCCs
# Collection 0xf17131a4c85e8a75ba52b3f91ce8c32f6f163924: 0 SCCs
# Collection 0xf198046ed564a0ce6785eb5f4ce205cb8194efe2: 0 SCCs
# Collection 0xf1e0beca4eac65f902466881cdfdd0099d91e47b: 0 SCCs
# Collection 0xf22862a58ba30b597b7e7e96fccba6e1d48243da: 0 SCCs
# Collection 0xf2407e08c0b9948800d6675e7d549b2d7761443b: 0 SCCs
# Collection 0xf30e2be919161cf7d7b975a7da101eae5da902ce: 0 SCCs
# Collection 0xf315ccd130b43c33a9a497c67dc3a4f7a0be54ae: 0 SCCs
# Collection 0xf31d7d9e68562e2b7100e83b500e07ea5fbf9e08: 0 SCCs
# Collection 0xf37e6ebd1cdc07b4d2ed6cb867beee33534e34de: 0 SCCs
# Collection 0xf3bb137b2a6d518700c6b7e85b05341599822397: 0 SCCs
# Collection 0xf3e778f839934fc819cfa1040aabacecba01e049: 0 SCCs
# Collection 0xf4680c917a873e2dd6ead72f9f433e74eb9c623c: 0 SCCs
# Collection 0xf4a8523509b7d2b8aa3173c665aef282547417a9: 0 SCCs
# Collection 0xf4e631fcff6d79c6c343a3da2d6b4424a3f33c2b: 0 SCCs
# Collection 0xf52fbd056ed1f1ab01d4296fce136d6c0a2bbfaf: 0 SCCs
# Collection 0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d: 0 SCCs
# Collection 0xf5dee1416988ec404000c6d8626910ecb3f62d6c: 0 SCCs
# Collection 0xf64dc33a192e056bb5f0e5049356a0498b502d50: 0 SCCs
# Collection 0xf71254147ab04be7bc7efd109641f0792de23af1: 0 SCCs
# Collection 0xf732a3d45484a363bccabd8ea4d0557821d75aa9: 0 SCCs
# Collection 0xf73c3710a8316b1d2b42cc7e59f1f5c2396a546f: 0 SCCs
# Collection 0xf766b3e7073f5a6483e27de20ea6f59b30b28f87: 0 SCCs
# Collection 0xf7a6e15dfd5cdd9ef12711bd757a9b6021abf643: 0 SCCs
# Collection 0xf8384521301b02a280984d4c623cd37a5a1ffc4b: 0 SCCs
# Collection 0xf85c874ea05e2225982b48c93a7c7f701065d91e: 0 SCCs
# Collection 0xf876bbc810e84854c9c37018103c0045544a6af9: 0 SCCs
# Collection 0xf87e31492faf9a91b02ee0deaad50d51d56d5d4d: 0 SCCs
# Collection 0xf8e94e7d4f2e2cc9a07512ae9813841a0000cb4e: 0 SCCs
# Collection 0xf90aeef57ae8bc85fe8d40a3f4a45042f4258c67: 0 SCCs
# Collection 0xf915bbfbb6c097dc327e64eec55e9ef4d110d627: 0 SCCs
# Collection 0xf980759616a795b2d692a5c0a0f1bad651984bc1: 0 SCCs
# Collection 0xf981b127253ffccc2f08e0ffb904b084be6bdf1a: 0 SCCs
# Collection 0xf9b3b38a458c2512b6680e1f3bc7a022e97d7dab: 0 SCCs
# Collection 0xfa69031b8f84ade91d1fac52148363842637699a: 0 SCCs
# Collection 0xfaafdc07907ff5120a76b34b731b278c38d6043c: 0 SCCs
# Collection 0xfb026c8edc423fa0aaeba2be812676e2f2d5da18: 0 SCCs
# Collection 0xfb37cffd0cfb8139833800ee5656963658912d5c: 0 SCCs
# Collection 0xfb6751d440406edc54136b3b803e8bdae3db8865: 0 SCCs
# Collection 0xfbeef911dc5821886e1dda71586d90ed28174b7d: 0 SCCs
# Collection 0xfc5b4fe32494dfe71fe20994264a6be7237ef9a8: 0 SCCs
# Collection 0xfc82b45321d9fb9f9bcdf4ae2fbacaaca552777d: 0 SCCs
# Collection 0xfc9908fed7cfc00bf0e0653e72f1eda3b0ee0982: 0 SCCs
# Collection 0xfcad2859f3e602d4cfb9aca35465a618f9009f7b: 0 SCCs
# Collection 0xfcf6033ad5cd537095da91d57d4ce0634307d7f0: 0 SCCs
# Collection 0xfd0ada243867eaec63e4669be7d78aba9e41cb57: 0 SCCs
# Collection 0xfd13cb7d8287eb7c09b04759231f8454b3fd81d6: 0 SCCs
# Collection 0xfd385556ebf6b183380afcd61efd8194d0d46520: 0 SCCs
# Collection 0xfd5683f0ca3e76b963ee997831f2c8b29fa7f81b: 0 SCCs
# Collection 0xfdda51b074d2213b5976396d8db36d48071646bd: 0 SCCs
# Collection 0xfe2bab90dd0dbbfe48ade8e29d66d38cba05f89e: 0 SCCs
# Collection 0xfe55b756e674e2a5874c9b79e5a59e0d07f271ee: 0 SCCs
# Collection 0xfe707abaead863313d926f7b369977c3b626678f: 0 SCCs
# Collection 0xfeb52cbf71b9adac957c6f948a6cf9980ac8c907: 0 SCCs
# Collection 0xff15b5f18889704cf4a05026858e299596c4793b: 0 SCCs
# Collection 0xff3559412c4618af7c6e6f166c74252ff6364456: 0 SCCs
# Collection 0xff480a7c447468a44f886daae019513386198c1b: 0 SCCs
# Collection 0xff6889ea7d06137edd949f8381a14f0ffc39ba80: 0 SCCs
# Collection 0xffc5043d9a00865d089d5eefa5b3d1625aec6763: 0 SCCs
# Collection 0xffdf17652cca46eb98a214cb3e413c8661241e49: 0 SCCs

# %%
sccs = detect_sccs(subset_multi_full, min_occurrences=10)
print(f"Detected suspicious SCCs (min_occurrences=10):")
for contract, scc_dict in sccs.items():
    if len(scc_dict) > 0:  # Only print collections with SCCs
        print(f"Collection {contract}: {len(scc_dict)} SCCs")
        for scc, count in list(scc_dict.items())[:5]:
            print(f"  SCC {list(scc)}: {count} occurrences")
# Out:
# Detected suspicious SCCs (min_occurrences=10):

# %%
total_sccs = sum(len(scc_dict) for scc_dict in sccs.values())
print(f"Total SCCs across all collections: {total_sccs}")
# Out:
# Total SCCs across all collections: 0

# %%
def detect_rapid_sequences(df, time_window_hours=12, price_deviation=0.05):
    suspicious_sequences = []
    df_sorted = df.sort_values('Datetime_updated_seconds')
    
    for nft_id in df_sorted['NFT_ID'].unique():
        nft_trades = df_sorted[df_sorted['NFT_ID'] == nft_id]
        if len(nft_trades) < 2:
            continue
        
        for i in range(len(nft_trades) - 1):
            start_trade = nft_trades.iloc[i]
            end_trade = nft_trades.iloc[i + 1]
            time_diff = end_trade['Datetime_updated_seconds'] - start_trade['Datetime_updated_seconds']
            if time_diff <= time_window_hours * 3600:
                price_change = abs(end_trade['Price_USD'] - start_trade['Price_USD']) / start_trade['Price_USD']
                if price_change <= price_deviation:
                    suspicious_sequences.append((start_trade['Transaction_hash'], end_trade['Transaction_hash']))
    
    return suspicious_sequences

# %% [raw]
# import time
# start = time.time()
# sequences = detect_rapid_sequences(subset_multi_full)
# print(f"Runtime: {(time.time() - start) / 60:.2f} minutes")
# print(f"Detected {len(sequences)} rapid sequences:")
# for i, (start_tx, end_tx) in enumerate(sequences[:5]):
#     print(f"Sequence {i + 1}: {start_tx} -> {end_tx}")

# %% [raw]
# low_var_cycles = cycles_df[cycles_df['Price_Variation'] <= 0.05]
# print(f"Cycles with <5% variation: {len(low_var_cycles)} (${low_var_cycles['Volume_USD'].sum():.2f})")

# %% [markdown]
# # 1. Temporal Clustering with Anomalous Price Dynamics
# Idea: Wash traders often execute rapid trades to inflate volume, but their price patterns may deviate from organic market trends (e.g., stable prices despite low liquidity or sudden spikes with no external trigger). Cluster transactions temporally and flag clusters with anomalous price behavior.
# Implementation:
# Use DBSCAN or HDBSCAN to cluster transactions by Datetime_updated_seconds within small time windows (e.g., 1 hour).
# For each cluster, compute price variance, trade frequency, and address overlap.
# Flag clusters with:
# High trade frequency (>10 trades/hour).
# Low price variance (<5%) or extreme spikes (>100% change without market-wide correlation).
# High address repetition (e.g., same Seller_address or Buyer_address in >50% of trades).

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# Normalize timestamps for clustering
X = subset_multi_full['Datetime_updated_seconds'].values.reshape(-1, 1) / 3600  # Hours
db = DBSCAN(eps=1, min_samples=5).fit(X)  # 1-hour radius, min 5 trades
subset_multi_full['Cluster'] = db.labels_

suspicious_clusters = []
for cluster_id in subset_multi_full['Cluster'].unique():
    if cluster_id == -1: continue  # Noise points
    cluster = subset_multi_full[subset_multi_full['Cluster'] == cluster_id]
    price_var = cluster['Price_USD'].var()
    addr_overlap = len(cluster['Seller_address'].value_counts()) / len(cluster)
    if len(cluster) > 10 and (price_var < 0.05 or price_var > 100) and addr_overlap > 0.5:
        suspicious_clusters.append(cluster)
print(f"Detected {len(suspicious_clusters)} suspicious temporal clusters")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\1209792369.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_multi_full['Cluster'] = db.labels_
# Detected 745 suspicious temporal clusters

# %% [markdown]
# ## Interpretaion:
# These 745 clusters suggest bursts of activity that deviate from organic trading patterns—either through artificial stability (low variance, classic wash trading) or manipulation attempts (high variance, price pumping).

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd

# Normalize timestamps for clustering (already done)
X = subset_multi_full['Datetime_updated_seconds'].values.reshape(-1, 1) / 3600  # Hours
db = DBSCAN(eps=1, min_samples=5).fit(X)
subset_multi_full['Cluster'] = db.labels_

# Analyze suspicious clusters
suspicious_clusters = []
cluster_stats = []

for cluster_id in subset_multi_full['Cluster'].unique():
    if cluster_id == -1: continue  # Noise points
    cluster = subset_multi_full[subset_multi_full['Cluster'] == cluster_id]
    price_var = cluster['Price_USD'].var()
    addr_overlap = len(cluster['Seller_address'].value_counts()) / len(cluster)
    
    if len(cluster) > 10 and (price_var < 0.05 or price_var > 100) and addr_overlap > 0.5:
        suspicious_clusters.append(cluster)
        stats = {
            'Cluster_ID': cluster_id,
            'Trade_Count': len(cluster),
            'Volume_USD': cluster['Price_USD'].sum(),
            'Price_Variance': price_var,
            'Unique_Sellers': cluster['Seller_address'].nunique(),
            'Unique_Buyers': cluster['Buyer_address'].nunique(),
            'Address_Overlap': addr_overlap,
            'Time_Span': (cluster['Datetime_updated_seconds'].max() - cluster['Datetime_updated_seconds'].min()) / 3600  # Hours
        }
        cluster_stats.append(stats)

# Convert to DataFrame for analysis
clusters_df = pd.DataFrame(cluster_stats)
clusters_df.to_csv('suspicious_clusters.csv', index=False)

# Summary statistics
print(f"Detected {len(suspicious_clusters)} suspicious temporal clusters")
print(f"Total suspicious volume: ${clusters_df['Volume_USD'].sum():.2f}")
print(f"Total suspicious trades: {clusters_df['Trade_Count'].sum()}")
print(f"Average trades per cluster: {clusters_df['Trade_Count'].mean():.2f}")
print(f"Average volume per cluster: ${clusters_df['Volume_USD'].mean():.2f}")
print(f"Percentage of subset volume: {(clusters_df['Volume_USD'].sum() / subset_multi_full['Price_USD'].sum()) * 100:.2f}%")
print(f"Low variance clusters (<0.05): {len(clusters_df[clusters_df['Price_Variance'] < 0.05])}")
print(f"High variance clusters (>100): {len(clusters_df[clusters_df['Price_Variance'] > 100])}")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\3502974190.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_multi_full['Cluster'] = db.labels_
# Detected 745 suspicious temporal clusters
# Total suspicious volume: $3072653.79
# Total suspicious trades: 51626
# Average trades per cluster: 69.30
# Average volume per cluster: $4124.37
# Percentage of subset volume: 0.68%
# Low variance clusters (<0.05): 0
# High variance clusters (>100): 745

# %% [markdown]
# ## Check overlap with your 2,381 cycles

# %%
cycle_txs = set.union(*[set([edge[0], edge[1]]) for cycle in cycles_full for edge in cycle])
cluster_txs = set.union(*[set(cluster['Seller_address']) | set(cluster['Buyer_address']) for cluster in suspicious_clusters])
overlap = len(cycle_txs & cluster_txs)
print(f"Address overlap between cycles and clusters: {overlap}")
# Out:
# Address overlap between cycles and clusters: 371

# %%
import matplotlib.pyplot as plt
plt.scatter(clusters_df['Time_Span'], clusters_df['Volume_USD'], c=clusters_df['Price_Variance'])
plt.xlabel('Time Span (hours)'); plt.ylabel('Volume (USD)')
plt.title('Suspicious Clusters')
plt.show()

# %% [markdown]
# # 2. Address Behavior Profiling with Machine Learning
# Idea: Wash traders exhibit distinct behaviors (e.g., high trade frequency with few partners, low profit motive). Use unsupervised learning to profile addresses and flag anomalies.
# Implementation:
# Features per address (Seller_address or Buyer_address):
# Trade count.
# Unique trade partners (Buyer_address or Seller_address).
# Average trade price and variance.
# Time between trades (mean and min).
# Percentage of trades within 12 hours.
# Apply Isolation Forest or Autoencoder to detect outliers.

# %%
from sklearn.ensemble import IsolationForest

addr_features = opensea.groupby('Seller_address').agg({
    'Buyer_address': ['count', 'nunique'],
    'Price_USD': ['mean', 'var'],
    'Datetime_updated_seconds': lambda x: (x.max() - x.min()) / len(x) if len(x) > 1 else 0
}).reset_index()
addr_features.columns = ['Seller_address', 'Trade_Count', 'Unique_Partners', 'Price_Mean', 'Price_Var', 'Avg_Time_Gap']
addr_features.fillna(0, inplace=True)

iso_forest = IsolationForest(contamination=0.01)  # Top 1% as anomalies
addr_features['Anomaly'] = iso_forest.fit_predict(addr_features.iloc[:, 1:])
suspicious_addrs = addr_features[addr_features['Anomaly'] == -1]['Seller_address']
print(f"Detected {len(suspicious_addrs)} suspicious addresses")
# Out:
# Detected 887 suspicious addresses

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd

# Compute address features (already done)
addr_features = opensea.groupby('Seller_address').agg({
    'Buyer_address': ['count', 'nunique'],
    'Price_USD': ['mean', 'var'],
    'Datetime_updated_seconds': lambda x: (x.max() - x.min()) / len(x) if len(x) > 1 else 0
}).reset_index()
addr_features.columns = ['Seller_address', 'Trade_Count', 'Unique_Partners', 'Price_Mean', 'Price_Var', 'Avg_Time_Gap']
addr_features.fillna(0, inplace=True)

# Detect anomalies
iso_forest = IsolationForest(contamination=0.01)  # Top 1% as anomalies
addr_features['Anomaly'] = iso_forest.fit_predict(addr_features.iloc[:, 1:])
suspicious_addrs = addr_features[addr_features['Anomaly'] == -1]['Seller_address']

# Quantify suspicious addresses
suspicious_trades = opensea[opensea['Seller_address'].isin(suspicious_addrs)]
suspicious_volume = suspicious_trades['Price_USD'].sum()
suspicious_tx_count = len(suspicious_trades)
total_volume = opensea['Price_USD'].sum()

# Additional metrics
avg_trades_per_addr = suspicious_trades.groupby('Seller_address').size().mean()
avg_partners_per_addr = suspicious_trades.groupby('Seller_address')['Buyer_address'].nunique().mean()
price_var_suspicious = suspicious_trades['Price_USD'].var()

# Overlap with cycles and clusters
cycle_addrs = set.union(*[set([edge[0], edge[1]]) for cycle in cycles_full for edge in cycle])
cluster_addrs = set.union(*[set(cluster['Seller_address']) | set(cluster['Buyer_address']) for cluster in suspicious_clusters])
overlap_cycles = len(set(suspicious_addrs) & cycle_addrs)
overlap_clusters = len(set(suspicious_addrs) & cluster_addrs)

# Print results
print(f"Detected {len(suspicious_addrs)} suspicious addresses")
print(f"Total suspicious volume: ${suspicious_volume:.2f}")
print(f"Total suspicious trades: {suspicious_tx_count}")
print(f"Percentage of total volume: {(suspicious_volume / total_volume) * 100:.2f}%")
print(f"Average trades per suspicious address: {avg_trades_per_addr:.2f}")
print(f"Average unique partners per suspicious address: {avg_partners_per_addr:.2f}")
print(f"Price variance among suspicious trades: {price_var_suspicious:.2f}")
print(f"Address overlap with cycles: {overlap_cycles}")
print(f"Address overlap with clusters: {overlap_clusters}")

# Save to CSV for further analysis
suspicious_trades.to_csv('suspicious_address_trades.csv', index=False)
addr_features[addr_features['Anomaly'] == -1].to_csv('suspicious_address_profiles.csv', index=False)
# Out:
# Detected 887 suspicious addresses
# Total suspicious volume: $384176823.02
# Total suspicious trades: 789348
# Percentage of total volume: 48.28%
# Average trades per suspicious address: 889.91
# Average unique partners per suspicious address: 274.56
# Price variance among suspicious trades: 211730527.30
# Address overlap with cycles: 88
# Address overlap with clusters: 345

# %%
### Require C++ stuff

# %% [raw]
# from torch_geometric.data import Data
# import torch
# from torch_geometric.nn import SAGEConv
#
# # Simplified graph (subset for demo)
# edges = subset_multi_full[['Seller_address', 'Buyer_address']].drop_duplicates()
# edge_index = torch.tensor([edges['Seller_address'].factorize()[0], edges['Buyer_address'].factorize()[0]], dtype=torch.long)
# data = Data(edge_index=edge_index)
# # GNN training and clustering would follow (complex, requires full setup)

# %%
import pandas as pd
import networkx as nx
from community import best_partition  # pip install python-louvain
import numpy as np

# Build the trading graph
G = nx.DiGraph()
for _, row in subset_multi_full.iterrows():
    G.add_edge(row['Seller_address'], row['Buyer_address'], weight=row['Price_USD'])

# Detect communities using Louvain algorithm
partition = best_partition(G.to_undirected())  # Undirected for community detection
communities = {}
for node, comm_id in partition.items():
    if comm_id not in communities:
        communities[comm_id] = []
    communities[comm_id].append(node)

# Analyze communities for suspicious activity
suspicious_communities = []
comm_stats = []

for comm_id, nodes in communities.items():
    if len(nodes) < 3: continue  # Skip small communities
    subgraph = G.subgraph(nodes)
    internal_trades = [(u, v) for u, v in subgraph.edges() if u in nodes and v in nodes]
    if not internal_trades: continue
    
    trade_df = subset_multi_full[
        (subset_multi_full['Seller_address'].isin(nodes)) & 
        (subset_multi_full['Buyer_address'].isin(nodes))
    ]
    volume = trade_df['Price_USD'].sum()
    trade_count = len(trade_df)
    avg_volume_per_trade = volume / trade_count if trade_count > 0 else 0
    
    # Flag communities with high internal volume or trade frequency
    if trade_count > 50 and (volume > 10000 or avg_volume_per_trade > 1000):
        suspicious_communities.append(trade_df)
        comm_stats.append({
            'Community_ID': comm_id,
            'Address_Count': len(nodes),
            'Trade_Count': trade_count,
            'Volume_USD': volume,
            'Avg_Volume_Per_Trade': avg_volume_per_trade,
            'Unique_NFTs': trade_df['NFT_ID'].nunique()
        })

# Convert to DataFrame and summarize
comm_df = pd.DataFrame(comm_stats)
comm_df.to_csv('suspicious_communities.csv', index=False)

print(f"Detected {len(suspicious_communities)} suspicious communities")
print(f"Total suspicious volume: ${comm_df['Volume_USD'].sum():.2f}")
print(f"Total suspicious trades: {comm_df['Trade_Count'].sum()}")
print(f"Average community size: {comm_df['Address_Count'].mean():.2f} addresses")
print(f"Average trades per community: {comm_df['Trade_Count'].mean():.2f}")
print(f"Percentage of subset volume: {(comm_df['Volume_USD'].sum() / subset_multi_full['Price_USD'].sum()) * 100:.2f}%")
# Out:
# Detected 75 suspicious communities
# Total suspicious volume: $305499208.36
# Total suspicious trades: 468564
# Average community size: 1656.67 addresses
# Average trades per community: 6247.52
# Percentage of subset volume: 67.60%

# %% [markdown]
# # Address Behavior Profiling

# %% [raw]
# # Refine features and add wash-specific filters
# addr_features['Trade_to_Partner_Ratio'] = addr_features['Trade_Count'] / addr_features['Unique_Partners']
# addr_features['Rapid_Trade_Pct'] = opensea.groupby('Seller_address').apply(
#     lambda x: (x['Datetime_updated_seconds'].diff().abs() < 12 * 3600).mean()
# ).reindex(addr_features['Seller_address']).fillna(0)
#
# # Redefine anomalies
# iso_forest = IsolationForest(contamination=0.01)
# features = addr_features[['Trade_Count', 'Unique_Partners', 'Price_Var', 'Trade_to_Partner_Ratio', 'Rapid_Trade_Pct']]
# addr_features['Anomaly'] = iso_forest.fit_predict(features)
#
# # Filter for wash-like behavior
# suspicious_addrs = addr_features[
#     (addr_features['Anomaly'] == -1) &
#     (addr_features['Trade_to_Partner_Ratio'] > 10) &  # High trades per partner
#     (addr_features['Rapid_Trade_Pct'] > 0.5)          # >50% trades within 12 hours
# ]['Seller_address']
#
# # Quantify
# suspicious_trades = opensea[opensea['Seller_address'].isin(suspicious_addrs)]
# suspicious_volume = suspicious_trades['Price_USD'].sum()
# print(f"Detected {len(suspicious_addrs)} suspicious addresses")
# print(f"Total suspicious volume: ${suspicious_volume:.2f}")
# print(f"Percentage of total volume: {(suspicious_volume / opensea['Price_USD'].sum()) * 100:.2f}%")

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd
import numpy as np

# Assuming addr_features is already defined from earlier
# Recreate it to ensure clarity
addr_features = opensea.groupby('Seller_address').agg({
    'Buyer_address': ['count', 'nunique'],
    'Price_USD': ['mean', 'var'],
    'Datetime_updated_seconds': lambda x: (x.max() - x.min()) / len(x) if len(x) > 1 else 0
}).reset_index()
addr_features.columns = ['Seller_address', 'Trade_Count', 'Unique_Partners', 'Price_Mean', 'Price_Var', 'Avg_Time_Gap']

# Add wash-specific features
addr_features['Trade_to_Partner_Ratio'] = addr_features['Trade_Count'] / addr_features['Unique_Partners']
addr_features['Rapid_Trade_Pct'] = opensea.groupby('Seller_address').apply(
    lambda x: (x['Datetime_updated_seconds'].diff().abs() < 12 * 3600).mean()
).reindex(addr_features['Seller_address']).fillna(0)

# Handle NaNs and Infs
addr_features['Price_Var'] = addr_features['Price_Var'].fillna(0)  # NaN variance for single trades
addr_features['Trade_to_Partner_Ratio'] = addr_features['Trade_to_Partner_Ratio'].replace([np.inf, -np.inf], 0).fillna(0)  # Handle division by zero
addr_features = addr_features.fillna(0)  # Catch any remaining NaNs

# Verify no NaNs remain
print("NaN check:", addr_features[['Trade_Count', 'Unique_Partners', 'Price_Var', 'Trade_to_Partner_Ratio', 'Rapid_Trade_Pct']].isna().sum())

# Redefine anomalies
iso_forest = IsolationForest(contamination=0.01, random_state=42)
features = addr_features[['Trade_Count', 'Unique_Partners', 'Price_Var', 'Trade_to_Partner_Ratio', 'Rapid_Trade_Pct']]
addr_features['Anomaly'] = iso_forest.fit_predict(features)

# Filter for wash-like behavior
suspicious_addrs = addr_features[
    (addr_features['Anomaly'] == -1) & 
    (addr_features['Trade_to_Partner_Ratio'] > 10) &  # High trades per partner
    (addr_features['Rapid_Trade_Pct'] > 0.5)          # >50% trades within 12 hours
]['Seller_address']

# Quantify
suspicious_trades = opensea[opensea['Seller_address'].isin(suspicious_addrs)]
suspicious_volume = suspicious_trades['Price_USD'].sum()
total_volume = opensea['Price_USD'].sum()

print(f"Detected {len(suspicious_addrs)} suspicious addresses")
print(f"Total suspicious volume: ${suspicious_volume:.2f}")
print(f"Percentage of total volume: {(suspicious_volume / total_volume) * 100:.2f}%")
print(f"Total suspicious trades: {len(suspicious_trades)}")
print(f"Average trades per suspicious address: {len(suspicious_trades) / len(suspicious_addrs) if len(suspicious_addrs) > 0 else 0:.2f}")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\1626961343.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   addr_features['Rapid_Trade_Pct'] = opensea.groupby('Seller_address').apply(
# NaN check: Trade_Count               0
# Unique_Partners           0
# Price_Var                 0
# Trade_to_Partner_Ratio    0
# Rapid_Trade_Pct           0
# dtype: int64
# Detected 0 suspicious addresses
# Total suspicious volume: $0.00
# Percentage of total volume: 0.00%
# Total suspicious trades: 0
# Average trades per suspicious address: 0.00

# %%
# Loosen filters
suspicious_addrs = addr_features[
    (addr_features['Anomaly'] == -1) & 
    (addr_features['Trade_to_Partner_Ratio'] > 3) &  # Lowered from 10
    (addr_features['Rapid_Trade_Pct'] > 0.2)         # Lowered from 0.5
]['Seller_address']

suspicious_trades = opensea[opensea['Seller_address'].isin(suspicious_addrs)]
suspicious_volume = suspicious_trades['Price_USD'].sum()
print(f"Detected {len(suspicious_addrs)} suspicious addresses")
print(f"Total suspicious volume: ${suspicious_volume:.2f}")
print(f"Percentage of total volume: {(suspicious_volume / opensea['Price_USD'].sum()) * 100:.2f}%")
# Out:
# Detected 0 suspicious addresses
# Total suspicious volume: $0.00
# Percentage of total volume: 0.00%

# %%
import pandas as pd
import numpy as np

# Recreate addr_features if not in memory
addr_features = opensea.groupby('Seller_address').agg({
    'Buyer_address': ['count', 'nunique'],
    'Price_USD': ['mean', 'var'],
    'Datetime_updated_seconds': lambda x: (x.max() - x.min()) / len(x) if len(x) > 1 else 0
}).reset_index()
addr_features.columns = ['Seller_address', 'Trade_Count', 'Unique_Partners', 'Price_Mean', 'Price_Var', 'Avg_Time_Gap']

# Add wash-specific features
addr_features['Trade_to_Partner_Ratio'] = addr_features['Trade_Count'] / addr_features['Unique_Partners']
addr_features['Rapid_Trade_Pct'] = opensea.groupby('Seller_address').apply(
    lambda x: (x['Datetime_updated_seconds'].diff().abs() < 12 * 3600).mean()
).reindex(addr_features['Seller_address']).fillna(0)

# Handle NaNs/Infs
addr_features['Price_Var'] = addr_features['Price_Var'].fillna(0)
addr_features['Trade_to_Partner_Ratio'] = addr_features['Trade_to_Partner_Ratio'].replace([np.inf, -np.inf], 0).fillna(0)
addr_features = addr_features.fillna(0)

# Rule-based wash trading detection
suspicious_addrs = addr_features[
    (addr_features['Trade_Count'] > 50) &          # High activity
    (addr_features['Trade_to_Partner_Ratio'] > 3) & # Low partner diversity
    (addr_features['Rapid_Trade_Pct'] > 0.2)       # Rapid trading
]['Seller_address']

# Quantify
suspicious_trades = opensea[opensea['Seller_address'].isin(suspicious_addrs)]
suspicious_volume = suspicious_trades['Price_USD'].sum()
total_volume = opensea['Price_USD'].sum()

print(f"Detected {len(suspicious_addrs)} suspicious addresses")
print(f"Total suspicious volume: ${suspicious_volume:.2f}")
print(f"Percentage of total volume: {(suspicious_volume / total_volume) * 100:.2f}%")
print(f"Total suspicious trades: {len(suspicious_trades)}")
print(f"Average trades per suspicious address: {len(suspicious_trades) / len(suspicious_addrs) if len(suspicious_addrs) > 0 else 0:.2f}")
# Out:
# Detected 0 suspicious addresses
# Total suspicious volume: $0.00
# Percentage of total volume: 0.00%
# Total suspicious trades: 0
# Average trades per suspicious address: 0.00
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\518666768.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   addr_features['Rapid_Trade_Pct'] = opensea.groupby('Seller_address').apply(

# %% [markdown]
# # Community Detection
# Adjust thresholds and use directed graph properties:

# %%
# Build directed graph
G = nx.DiGraph()
for _, row in subset_multi_full.iterrows():
    G.add_edge(row['Seller_address'], row['Buyer_address'], weight=row['Price_USD'])

# Community detection on directed graph (use weakly connected components + volume filter)
communities = list(nx.weakly_connected_components(G))
suspicious_communities = []
comm_stats = []

for nodes in communities:
    if len(nodes) < 5 or len(nodes) > 100: continue  # Tighten size range
    trade_df = subset_multi_full[
        (subset_multi_full['Seller_address'].isin(nodes)) & 
        (subset_multi_full['Buyer_address'].isin(nodes))
    ]
    if len(trade_df) < 20: continue
    volume = trade_df['Price_USD'].sum()
    if volume > 5000 and len(trade_df) / len(nodes) > 5:  # High trade density
        suspicious_communities.append(trade_df)
        comm_stats.append({
            'Address_Count': len(nodes),
            'Trade_Count': len(trade_df),
            'Volume_USD': volume
        })

comm_df = pd.DataFrame(comm_stats)
print(f"Detected {len(suspicious_communities)} suspicious communities")
print(f"Total suspicious volume: ${comm_df['Volume_USD'].sum():.2f}")
print(f"Percentage of subset volume: {(comm_df['Volume_USD'].sum() / subset_multi_full['Price_USD'].sum()) * 100:.2f}%")
# Out:
# Detected 11 suspicious communities
# Total suspicious volume: $1903889.68
# Percentage of subset volume: 0.42%

# %%
import pandas as pd
import networkx as nx
from community import best_partition

# Assuming G and communities are defined from earlier
G = nx.DiGraph()
for _, row in subset_multi_full.iterrows():
    G.add_edge(row['Seller_address'], row['Buyer_address'], weight=row['Price_USD'])
partition = best_partition(G.to_undirected())
communities = {}
for node, comm_id in partition.items():
    if comm_id not in communities:
        communities[comm_id] = []
    communities[comm_id].append(node)

# Detect suspicious communities with relaxed filters
suspicious_communities = []
comm_stats = []

for nodes in communities.values():  # Use .values() for iteration
    if len(nodes) < 5 or len(nodes) > 100: continue
    trade_df = subset_multi_full[
        (subset_multi_full['Seller_address'].isin(nodes)) & 
        (subset_multi_full['Buyer_address'].isin(nodes))
    ]
    if len(trade_df) < 10: continue  # Lowered from 20
    volume = trade_df['Price_USD'].sum()
    price_var = trade_df['Price_USD'].var()
    addr_overlap = trade_df['Seller_address'].nunique() / len(trade_df)
    trade_density = len(trade_df) / len(nodes)
    
    # Relaxed conditions
    if volume > 2000 and trade_density > 2 and (price_var < 1 or price_var > 50) and addr_overlap > 0.3:
        suspicious_communities.append(trade_df)
        comm_stats.append({
            'Address_Count': len(nodes),
            'Trade_Count': len(trade_df),
            'Volume_USD': volume,
            'Price_Variance': price_var,
            'Address_Overlap': addr_overlap
        })

# Handle empty case
comm_df = pd.DataFrame(comm_stats)
if not comm_df.empty:
    total_volume = comm_df['Volume_USD'].sum()
    volume_pct = (total_volume / subset_multi_full['Price_USD'].sum()) * 100
else:
    total_volume = 0
    volume_pct = 0

print(f"Detected {len(suspicious_communities)} suspicious communities")
print(f"Total suspicious volume: ${total_volume:.2f}")
print(f"Percentage of subset volume: {volume_pct:.2f}%")
if not comm_df.empty:
    print(f"Average community size: {comm_df['Address_Count'].mean():.2f} addresses")
    print(f"Average trades per community: {comm_df['Trade_Count'].mean():.2f}")
# Out:
# Detected 21 suspicious communities
# Total suspicious volume: $1112340.88
# Percentage of subset volume: 0.25%
# Average community size: 11.19 addresses
# Average trades per community: 30.71

# %%
print("done")
# Out:
# done

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.table import table

# Data from your ipynb
full_tx_count = 1899327  # Total transactions
full_volume = 795774046.42  # Total volume
subset_tx_count = 710691  # Subset transactions
subset_volume = 452189389.06  # Subset volume from cluster results
total_nfts = 366533  # Unique NFTs
multi_nfts = 244177  # Multi-trade NFTs

# Create table data
data = {
    'Dataset': ['Full OpenSea', 'Multi-Trade Subset'],
    'Transaction Count': [full_tx_count, subset_tx_count],
    'Total Volume (USD)': [f"${full_volume:,.2f}", f"${subset_volume:,.2f}"],
    'Unique NFTs': [total_nfts, multi_nfts]
}
df_table = pd.DataFrame(data)

# Plot table
fig, ax = plt.subplots(figsize=(8, 2))
ax.axis('off')
tbl = table(ax, cellText=df_table.values, colLabels=df_table.columns, loc='center', cellLoc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(10)
tbl.scale(1.2, 1.2)
plt.title('Dataset Summary for Cycle Detection', fontsize=12, pad=10)
plt.tight_layout()

# Save image
plt.savefig('cycle_detection_data_table.png', dpi=300, bbox_inches='tight')
print("Image saved as 'cycle_detection_data_table.png'")
plt.show()
# Out:
# Image saved as 'cycle_detection_data_table.png'

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# Sample 10,000 timestamps from subset_multi_full (adjust if needed)
timestamps = subset_multi_full['Datetime_updated_seconds'].sample(10000, random_state=42).values / 3600  # Convert to hours
X = timestamps.reshape(-1, 1)

# Apply DBSCAN (simplified for visualization)
db = DBSCAN(eps=1, min_samples=5).fit(X)
labels = db.labels_

# Plot
plt.figure(figsize=(10, 4))
plt.scatter(timestamps, np.zeros_like(timestamps), c=labels, cmap='viridis', s=10)
plt.xlabel('Time (Hours)', fontsize=12)
plt.yticks([])  # No y-axis needed
plt.title('Sample Temporal Clustering with DBSCAN (ε = 1 hour)', fontsize=14)
plt.colorbar(label='Cluster Label (-1 = Noise)')
plt.tight_layout()

# Save image
plt.savefig('temporal_clustering_sample.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Sample a small subset of edges (e.g., first 50 trades from a community)
sample_edges = subset_multi_full[['Seller_address', 'Buyer_address']].head(50)
G_sample = nx.from_pandas_edgelist(sample_edges, 'Seller_address', 'Buyer_address', create_using=nx.DiGraph())

# Plot
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G_sample)
nx.draw(G_sample, pos, node_size=50, node_color='skyblue', edge_color='gray', with_labels=False, arrows=True)
plt.title('Sample Trading Network for Community Detection', fontsize=14)
plt.tight_layout()

# Save image
plt.savefig('community_detection_sample.png', dpi=300, bbox_inches='tight')
plt.show()
print("Image saved as 'community_detection_sample.png'")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_27784\3415539433.py:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Image saved as 'community_detection_sample.png'

# %%
import matplotlib.pyplot as plt

# Data from results
methods = ['Cycles', 'Clusters', 'Communities']
volumes = [8423447.57, 3072653.79, 1112340.88]  # Suspicious volumes
percentages = [1.06, 0.68, 0.25]  # % of total or subset volume

# Bar chart
fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(methods, volumes, color=['#1f77b4', '#ff7f0e', '#2ca02c'])
ax.set_ylabel('Suspicious Volume (USD)', fontsize=12)
ax.set_title('Suspicious Trading Volumes by Detection Method', fontsize=14)
ax2 = ax.twinx()
ax2.plot(methods, percentages, color='red', marker='o', linestyle='--')
ax2.set_ylabel('Percentage (%)', fontsize=12, color='red')
ax2.tick_params(axis='y', labelcolor='red')
for bar, perc in zip(bars, percentages):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{perc:.2f}%', 
            ha='center', va='bottom', fontsize=10)
plt.tight_layout()

# Save image
plt.savefig('suspicious_volumes_bar.png', dpi=300, bbox_inches='tight')
plt.show()
print("Image saved as 'suspicious_volumes_bar.png'")
# Out:
# Image saved as 'suspicious_volumes_bar.png'

# %%
import matplotlib.pyplot as plt

# Data from results
labels = ['Cycles', 'Clusters', 'Communities']
volumes = [8423447.57, 3072653.79, 1112340.88]
total = sum(volumes)

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(volumes, labels=labels, autopct=lambda p: f'${p*total/100:,.0f}\n{p:.1f}%', 
        colors=['#1f77b4', '#ff7f0e', '#2ca02c'], startangle=90)
plt.title('Distribution of Suspicious Trading Volume', fontsize=14)
plt.tight_layout()

# Save image
plt.savefig('suspicious_volume_pie.png', dpi=300, bbox_inches='tight')
plt.show()
print("Image saved as 'suspicious_volume_pie.png'")
# Out:
# Image saved as 'suspicious_volume_pie.png'

# %%
print("comm_df columns:", comm_df.columns.tolist())
# Out:
# comm_df columns: ['Address_Count', 'Trade_Count', 'Volume_USD', 'Price_Variance', 'Address_Overlap']

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# Print column names for confirmation
print("comm_df columns:", comm_df.columns.tolist())
print("cycles_df columns:", cycles_df.columns.tolist())

# Step 1: Select top community by volume (for context)
comm_df = comm_df.sort_values('Volume_USD', ascending=False)
top_community = comm_df.iloc[0]
print("Top community stats:", top_community.to_dict())

# Step 2: Get all cycle addresses from cycles_df
cycle_addresses_col = 'Addresses'  # Confirmed column
all_cycle_addresses = set()
for addr_list in cycles_df[cycle_addresses_col]:
    all_cycle_addresses.update(addr_list)  # addr_list is already a list
print(f"Total unique cycle addresses: {len(all_cycle_addresses)}")

# Step 3: Filter trades involving cycle addresses from subset_multi_full
cycle_trades = subset_multi_full[
    subset_multi_full['Seller_address'].isin(all_cycle_addresses) |
    subset_multi_full['Buyer_address'].isin(all_cycle_addresses)
].head(200)  # Limit to 200 for clarity
comm_addresses = set(cycle_trades['Seller_address']).union(cycle_trades['Buyer_address'])
print(f"Trades in cycle-related network: {len(cycle_trades)}")
print(f"Addresses in cycle-related network: {len(comm_addresses)}")

# Step 4: Extract cycle edges from cycles_df
comm_cycle_edges = []
for addr_list in cycles_df[cycle_addresses_col]:
    for i in range(len(addr_list) - 1):
        comm_cycle_edges.append((addr_list[i], addr_list[i + 1]))
    comm_cycle_edges.append((addr_list[-1], addr_list[0]))  # Close the loop
print(f"Total cycle edges: {len(comm_cycle_edges)}")

# Step 5: Build the directed graph
G = nx.DiGraph()
for _, row in cycle_trades.iterrows():
    G.add_edge(row['Seller_address'], row['Buyer_address'], weight=row['Price_USD'], nft_id=row['NFT_ID'])

# Step 6: Plot the network
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, k=0.5, iterations=50)

# Draw all edges
nx.draw_networkx_edges(G, pos, edge_color='gray', alpha=0.3, arrows=True)

# Highlight cycle edges in red
cycle_edges_in_graph = [(u, v) for (u, v) in comm_cycle_edges if G.has_edge(u, v)]
nx.draw_networkx_edges(G, pos, edgelist=cycle_edges_in_graph, edge_color='red', width=2, arrows=True)

# Draw nodes with size by degree
node_degrees = dict(G.degree())
nx.draw_networkx_nodes(G, pos, node_size=[v * 50 for v in node_degrees.values()], 
                       node_color='skyblue', alpha=0.7)

# Label top 5 nodes
top_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)[:5]
labels = {node: node[:8] + '...' for node in top_nodes}
nx.draw_networkx_labels(G, pos, labels, font_size=8)

# Customize plot
plt.title('Trading Network with Wash Trading Cycles\n(Based on Detected Cycles)', fontsize=14, pad=20)
plt.axis('off')
plt.tight_layout()

# Save image
plt.savefig('complex_trading_network.png', dpi=300, bbox_inches='tight')
plt.show()
print("Image saved as 'complex_trading_network.png'")
# Out:
# comm_df columns: ['Address_Count', 'Trade_Count', 'Volume_USD', 'Price_Variance', 'Address_Overlap']
# cycles_df columns: ['NFT_ID', 'Addresses', 'Prices', 'Timestamps', 'Volume_USD', 'Price_Variation', 'Time_Span']
# Top community stats: {'Address_Count': 69.0, 'Trade_Count': 193.0, 'Volume_USD': 378080.20661, 'Price_Variance': 585051.4548858472, 'Address_Overlap': 0.3471502590673575}
# Total unique cycle addresses: 1093
# Trades in cycle-related network: 200
# Addresses in cycle-related network: 150
# Total cycle edges: 7742
# Image saved as 'complex_trading_network.png'

# %%
print("done")
# Out:
# done
